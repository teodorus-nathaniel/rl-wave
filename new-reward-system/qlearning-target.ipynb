# %%
sys.path.insert(0, './common')

import numpy as np
from collections import deque
import sys
import wave
import qlearning_target_model

# %%
env = wave.WaveEnv()
# Out:
# WAVE environment created.

# %%
model = qlearning_target_model.QLearning(64, 2, 1024)
save_path = './models/qlearning-target.pth'
model.set_model_save_path(save_path)

# %%
model.load_model()
# Out:
# Model loaded

# %%
model.set_train_params(max_step=2000)
model.train(env, 1000, show_plot=True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# EPOCH: 999, total reward: -4.205501556396484, timestep: 43, epsilon: 0.049999999999999156

# %%
model.plot_train_memory()

# %%
model.save_model()
# Out:
# Model Saved

# %%
env = wave.WaveEnv(3)
model.test(env)
# Out:
# WAVE environment created.
# (16.75132606801344, 294)

# %%
env.close()
