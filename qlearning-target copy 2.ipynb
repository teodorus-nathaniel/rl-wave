# %%
sys.path.insert(0, './common')

import sys
import wave
import qlearning_target_model

# %%
env_path = 'env01/Wave'

# %%
env = wave.WaveEnv(env_path, timescale=30, worker_id=21)
# Out:
# WAVE environment created.

# %%
model = qlearning_target_model.QLearning(127, 2, 512)

# %%
# save_path = './results/env01/qlearning_target/512-final-new' ini oke ampe 4000
save_path = './results/env01/qlearning_target/512-final-new-decay-more-new'
model.set_model_save_path(save_path)

# %%
model.load_model()
# Out:
# Model loaded
# Training history loaded

# %%
model.set_train_params(max_step=1000, batch_size=512, start_epsilon=1, mem_size=1_000_000, min_epsilon=0.01, lr_decay_interval=250)
model.train(env, 5000, show_plot=True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Model saved
# Training history saved
# saved to ./results/env01/qlearning_target/512-final-new-decay-more-new
# EPOCH: 4999, total reward: 94.25997161865234, timestep: 415, epsilon: 0.009998671593271896, lr: 1.350851717672993e-05

# %%
model.plot_train_memory(smooth=100)

# %%
model.save_model()
# Out:
# Model saved
# Training history saved

# %%
env = wave.WaveEnv(env_path, 1)
model.test(env)

# %%
model.test_avg(env, 10)
# Out:
# 219.9999729692936 1000
# 143.5199784785509 630
# -2.4500015676021576 149
# 149.83998115360737 704
# 59.24999526143074 315
# 48.729993507266045 326
# 142.37998078763485 753
# 224.99997325241566 1000
# 244.9999677091837 1000
# 140.73998376727104 586
# ([219.9999729692936,
#   143.5199784785509,
#   -2.4500015676021576,
#   149.83998115360737,
#   59.24999526143074,
#   48.729993507266045,
#   142.37998078763485,
#   224.99997325241566,
#   244.9999677091837,
#   140.73998376727104],
#  [1000, 630, 149, 704, 315, 326, 753, 1000, 1000, 586],
#  137.20098253190517,
#  646.3)

# %%
# qlearning 10,000 episode (386.0179519353807, 1598.09)

# %%
env.close()
