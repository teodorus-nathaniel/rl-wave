# %%
sys.path.insert(0, './common')

import numpy as np
from collections import deque
import sys
import wave
import a2c_model

# %%
env = wave.WaveEnv(40)
# Out:
# WAVE environment created.

# %%
model = a2c_model.A2C(64, 2, 1024, lr=1e-4)
save_path = './models/a2c.pth'
model.set_model_save_path(save_path)

# %%
model.load_model()
# Out:
# Model loaded

# %%
model.train(env, 10000, show_plot=True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# EPOCH: 2469, total reward: 28.875923017039895, timestep: 269
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# e:\Nathan\!SKRIPSI\rl-wave\multiple-obs\a2c.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/Nathan/%21SKRIPSI/rl-wave/multiple-obs/a2c.ipynb#ch0000003?line=0'>1</a> model.train(env, 10000, show_plot=True)
#
# File e:\Nathan\!SKRIPSI\rl-wave\multiple-obs\./common\a2c_model.py:133, in A2C.train(self, env, epoch, reset_memory, show_plot)
# ...

# %%
model.save_model()

# %%
model.plot_train_memory()

# %%
env = wave.WaveEnv(3)
model.test(env)
# Out:
# WAVE environment created.
# (257.59933601506054, 2068)

# %%
env.close()
