# %%
sys.path.insert(0, './common')

import numpy as np
from collections import deque
import sys
import wave
import qlearning_target_model

# %%
env = wave.WaveEnv()
# Out:
# WAVE environment created.

# %%
model = qlearning_target_model.QLearning(64, 2, 1024)
save_path = './models/qlearning-target.pth'
model.set_model_save_path(save_path)

# %%
model.load_model()
# Out:
# Model loaded

# %%
model.train(env, 2000)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# EPOCH: 1999, total reward: 20.940269470214844, timestep: 272, epsilon: 0.04950000000005467

# %%
model.plot_train_memory()

# %%
model.save_model()
# Out:
# Model Saved

# %%
env = wave.WaveEnv(3)
model.test(env)
# Out:
# WAVE environment created.
# (-3.0634958632290363, 60)

# %%
env.close()
