# %%
from mlagents_envs.environment import ActionTuple, UnityEnvironment, BaseEnv
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel
import numpy as np
import torch
import random
from collections import deque
import copy
import matplotlib.pyplot as plt

# %%
channel = EngineConfigurationChannel()
env = UnityEnvironment(file_name='./Wave', seed=1, side_channels=[channel])
channel.set_configuration_parameters(time_scale = 40)
print("WAVE environment created.")
# Out:
# WAVE environment created.

# %%
def copy_model(model):
    model2 = copy.deepcopy(model)
    model2.load_state_dict(model.state_dict())
    return model2

# %%
l1 = 64
l2 = 512
l3 = 512
l4 = 2

model = torch.nn.Sequential(
  torch.nn.Linear(l1, l2),
  torch.nn.ReLU(),
  torch.nn.Linear(l2, l3),
  torch.nn.ReLU(),
  torch.nn.Linear(l3, l4),
)
model_copy = copy_model(model)

learning_rate = 1e-4
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def loss_fn(pred, target):
    return torch.mean(0.5 * (pred - target) ** 2)

def preprocess_input(inp):
    return np.append(inp.obs[1], inp.obs[0], axis=1)

# %%
model_path = './models/qlearning-target-multi-obs.path'
try:
    model.load_state_dict(torch.load(model_path))
    print('Model loaded')
except:
    print('No model available')
# Out:
# Model loaded

# %%
EPOCH = 2000
MEM_SIZE = 2500
MIN_EPSILON = .05
MAX_STEP = 500
BATCH_SIZE = 256
GAMMA = 0.9
SYNC_INTERVAL = 1000

epsilon = 1

losses = []
all_rewards = []
all_timesteps = []
experiences = deque(maxlen=MEM_SIZE)

k = 0
for i in range(EPOCH):
    env.reset()
    behavior_name = list(env.behavior_specs)[0]

    j = 0
    epoch_rewards = []
    while j < MAX_STEP:
        j += 1
        k += 1
        decision_steps, terminal_steps = env.get_steps(behavior_name)
        if (len(terminal_steps) > 0):
            break

        state = torch.Tensor(preprocess_input(decision_steps))

        qval = model(state)
        if np.random.rand() > epsilon:
            # exploit
            action = np.argmax(qval.detach().numpy())
        else:
            # explore
            action = np.random.randint(0, 2)

        action_tuple = ActionTuple()
        action_tuple.add_discrete(np.array([[action]]))
        env.set_actions(behavior_name, action_tuple)
        env.step()

        new_decision_steps, new_terminal_steps = env.get_steps(behavior_name)
        current_step = new_decision_steps if len(new_terminal_steps) == 0 else new_terminal_steps
        reward = current_step.reward[0]

        epoch_rewards.append(reward)
    
        state2 = torch.Tensor(preprocess_input(current_step))
        done = len(new_terminal_steps) > 0

        current_exp = (state, action, reward, state2, done)
        experiences.append(current_exp)

        if len(experiences) >= BATCH_SIZE:
            batch = random.sample(experiences, BATCH_SIZE)

            states = torch.cat([s for (s, a, r, s2, done) in batch])
            actions = torch.Tensor([a for (s, a, r, s2, done) in batch])
            states2 = torch.cat([s2 for (s, a, r, s2, done) in batch])
            done_data = torch.Tensor([done for (s, a, r, s2, done) in batch])
            rewards = torch.Tensor([r for (s, a, r, s2, done) in batch])

            qvals = model(states)

            with torch.no_grad():
                qvals_2 = model_copy(states2)

            target = rewards + GAMMA * ((1 - done_data) * torch.max(qvals_2, dim=1)[0])
            action_qval_pred = qvals.gather(dim=1, index=actions.long().unsqueeze(dim=1)).squeeze()
            err = loss_fn(action_qval_pred, target.detach())
            losses.append(err.item())

            optimizer.zero_grad()
            err.backward()
            optimizer.step()
        
        if k % SYNC_INTERVAL == 0:
            model_copy = copy_model(model)

    current_reward = np.sum(epoch_rewards)
    all_rewards.append(current_reward)
    all_timesteps.append(j)
    print(f'EPOCH: {i}, total reward: {current_reward}, timestep: {j}, epsilon: {epsilon}')
    if epsilon > MIN_EPSILON:
        epsilon -= 1 / EPOCH

env.close()
# Out:
# EPOCH: 0, total reward: 36.526222229003906, timestep: 89, epsilon: 1
# EPOCH: 1, total reward: 15.471611022949219, timestep: 48, epsilon: 0.9995
# EPOCH: 2, total reward: 27.918659210205078, timestep: 80, epsilon: 0.9990000000000001
# EPOCH: 3, total reward: 11.161234855651855, timestep: 54, epsilon: 0.9985000000000002
# EPOCH: 4, total reward: 1.7650108337402344, timestep: 24, epsilon: 0.9980000000000002
# EPOCH: 5, total reward: 14.67995834350586, timestep: 49, epsilon: 0.9975000000000003
# EPOCH: 6, total reward: 3.020742416381836, timestep: 28, epsilon: 0.9970000000000003
# EPOCH: 7, total reward: 7.127837657928467, timestep: 49, epsilon: 0.9965000000000004
# EPOCH: 8, total reward: 11.159540176391602, timestep: 40, epsilon: 0.9960000000000004
# EPOCH: 9, total reward: 18.430484771728516, timestep: 54, epsilon: 0.9955000000000005
# EPOCH: 10, total reward: 11.158968925476074, timestep: 51, epsilon: 0.9950000000000006
# EPOCH: 11, total reward: 19.404338836669922, timestep: 52, epsilon: 0.9945000000000006
# EPOCH: 12, total reward: 2.2075939178466797, timestep: 26, epsilon: 0.9940000000000007
# EPOCH: 13, total reward: 65.14987182617188, timestep: 127, epsilon: 0.9935000000000007
# EPOCH: 14, total reward: 69.72846221923828, timestep: 139, epsilon: 0.9930000000000008
# EPOCH: 15, total reward: 2.966672897338867, timestep: 26, epsilon: 0.9925000000000008
# EPOCH: 16, total reward: 12.395124435424805, timestep: 39, epsilon: 0.9920000000000009
# EPOCH: 17, total reward: 35.23388671875, timestep: 77, epsilon: 0.9915000000000009
# EPOCH: 18, total reward: 28.971214294433594, timestep: 77, epsilon: 0.991000000000001
# EPOCH: 19, total reward: 19.598560333251953, timestep: 53, epsilon: 0.990500000000001
# EPOCH: 20, total reward: 6.544564247131348, timestep: 38, epsilon: 0.9900000000000011
# EPOCH: 21, total reward: 7.003593444824219, timestep: 40, epsilon: 0.9895000000000012
# EPOCH: 22, total reward: 27.926401138305664, timestep: 73, epsilon: 0.9890000000000012
# EPOCH: 23, total reward: 26.120267868041992, timestep: 67, epsilon: 0.9885000000000013
# EPOCH: 24, total reward: 35.43535614013672, timestep: 88, epsilon: 0.9880000000000013
# EPOCH: 25, total reward: 3.3063135147094727, timestep: 26, epsilon: 0.9875000000000014
# EPOCH: 26, total reward: 27.846435546875, timestep: 77, epsilon: 0.9870000000000014
# EPOCH: 27, total reward: 6.509268760681152, timestep: 37, epsilon: 0.9865000000000015
# EPOCH: 28, total reward: 15.719704627990723, timestep: 50, epsilon: 0.9860000000000015
# EPOCH: 29, total reward: 11.00561809539795, timestep: 53, epsilon: 0.9855000000000016
# EPOCH: 30, total reward: 9.505452156066895, timestep: 41, epsilon: 0.9850000000000017
# EPOCH: 31, total reward: 11.768182754516602, timestep: 50, epsilon: 0.9845000000000017
# EPOCH: 32, total reward: 2.924419403076172, timestep: 28, epsilon: 0.9840000000000018
# EPOCH: 33, total reward: 27.692825317382812, timestep: 77, epsilon: 0.9835000000000018
# EPOCH: 34, total reward: 9.958005905151367, timestep: 50, epsilon: 0.9830000000000019
# EPOCH: 35, total reward: 14.908437728881836, timestep: 53, epsilon: 0.9825000000000019
# EPOCH: 36, total reward: 12.27817440032959, timestep: 49, epsilon: 0.982000000000002
# EPOCH: 37, total reward: 10.531219482421875, timestep: 41, epsilon: 0.981500000000002
# EPOCH: 38, total reward: 2.7797670364379883, timestep: 39, epsilon: 0.9810000000000021
# EPOCH: 39, total reward: 38.2547721862793, timestep: 89, epsilon: 0.9805000000000021
# EPOCH: 40, total reward: 8.070259094238281, timestep: 40, epsilon: 0.9800000000000022
# EPOCH: 41, total reward: 11.205362319946289, timestep: 49, epsilon: 0.9795000000000023
# EPOCH: 42, total reward: 3.595277786254883, timestep: 39, epsilon: 0.9790000000000023
# EPOCH: 43, total reward: 2.9131412506103516, timestep: 29, epsilon: 0.9785000000000024
# EPOCH: 44, total reward: 12.612039566040039, timestep: 49, epsilon: 0.9780000000000024
# EPOCH: 45, total reward: 11.211380958557129, timestep: 53, epsilon: 0.9775000000000025
# EPOCH: 46, total reward: 2.762286901473999, timestep: 25, epsilon: 0.9770000000000025
# EPOCH: 47, total reward: 11.741902351379395, timestep: 51, epsilon: 0.9765000000000026
# EPOCH: 48, total reward: 21.834930419921875, timestep: 65, epsilon: 0.9760000000000026
# EPOCH: 49, total reward: 12.742361068725586, timestep: 40, epsilon: 0.9755000000000027
# EPOCH: 50, total reward: 23.93122100830078, timestep: 75, epsilon: 0.9750000000000028
# EPOCH: 51, total reward: 2.7431955337524414, timestep: 27, epsilon: 0.9745000000000028
# EPOCH: 52, total reward: 2.907522201538086, timestep: 28, epsilon: 0.9740000000000029
# EPOCH: 53, total reward: 27.294178009033203, timestep: 74, epsilon: 0.9735000000000029
# EPOCH: 54, total reward: 61.16465759277344, timestep: 128, epsilon: 0.973000000000003
# EPOCH: 55, total reward: 24.18085479736328, timestep: 64, epsilon: 0.972500000000003
# EPOCH: 56, total reward: 9.54792594909668, timestep: 41, epsilon: 0.9720000000000031
# EPOCH: 57, total reward: 12.391716003417969, timestep: 48, epsilon: 0.9715000000000031
# EPOCH: 58, total reward: 27.830326080322266, timestep: 67, epsilon: 0.9710000000000032
# EPOCH: 59, total reward: 2.22308611869812, timestep: 25, epsilon: 0.9705000000000032
# EPOCH: 60, total reward: 15.812942504882812, timestep: 53, epsilon: 0.9700000000000033
# EPOCH: 61, total reward: 11.467981338500977, timestep: 48, epsilon: 0.9695000000000034
# EPOCH: 62, total reward: 9.517471313476562, timestep: 41, epsilon: 0.9690000000000034
# EPOCH: 63, total reward: 6.369266986846924, timestep: 41, epsilon: 0.9685000000000035
# EPOCH: 1509, total reward: 19.188796997070312, timestep: 41, epsilon: 0.24550000000005484
# EPOCH: 1510, total reward: 27.593780517578125, timestep: 51, epsilon: 0.24500000000005484
# EPOCH: 1511, total reward: 19.47614097595215, timestep: 50, epsilon: 0.24450000000005484
# EPOCH: 1512, total reward: 81.92424011230469, timestep: 138, epsilon: 0.24400000000005484
# EPOCH: 1513, total reward: 19.580684661865234, timestep: 44, epsilon: 0.24350000000005484
# EPOCH: 1514, total reward: 40.00078582763672, timestep: 61, epsilon: 0.24300000000005484
# EPOCH: 1515, total reward: 52.85206604003906, timestep: 105, epsilon: 0.24250000000005484
# EPOCH: 1516, total reward: 77.81103515625, timestep: 113, epsilon: 0.24200000000005484
# EPOCH: 1517, total reward: 38.47429656982422, timestep: 64, epsilon: 0.24150000000005484
# EPOCH: 1518, total reward: 6.2437663078308105, timestep: 25, epsilon: 0.24100000000005484
# EPOCH: 1519, total reward: 19.558273315429688, timestep: 39, epsilon: 0.24050000000005484
# EPOCH: 1520, total reward: 19.620628356933594, timestep: 40, epsilon: 0.24000000000005484
# EPOCH: 1521, total reward: 108.64750671386719, timestep: 175, epsilon: 0.23950000000005484
# EPOCH: 1522, total reward: 10.40413761138916, timestep: 27, epsilon: 0.23900000000005484
# EPOCH: 1523, total reward: 219.5047607421875, timestep: 318, epsilon: 0.23850000000005483
# EPOCH: 1524, total reward: 182.36337280273438, timestep: 285, epsilon: 0.23800000000005483
# EPOCH: 1525, total reward: 80.07107543945312, timestep: 117, epsilon: 0.23750000000005483
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# e:\Nathan\!SKRIPSI\rl-wave\multiple-obs\model-qlearning-target.ipynb Cell 7' in <cell line: 17>()
#      <a href='vscode-notebook-cell:/e%3A/Nathan/%21SKRIPSI/rl-wave/multiple-obs/model-qlearning-target.ipynb#ch0000006?line=62'>63</a> done_data = torch.Tensor([done for (s, a, r, s2, done) in batch])
#      <a href='vscode-notebook-cell:/e%3A/Nathan/%21SKRIPSI/rl-wave/multiple-obs/model-qlearning-target.ipynb#ch0000006?line=63'>64</a> rewards = torch.Tensor([r for (s, a, r, s2, done) in batch])
# ---> <a href='vscode-notebook-cell:/e%3A/Nathan/%21SKRIPSI/rl-wave/multiple-obs/model-qlearning-target.ipynb#ch0000006?line=65'>66</a> qvals = model(states)
#      <a href='vscode-notebook-cell:/e%3A/Nathan/%21SKRIPSI/rl-wave/multiple-obs/model-qlearning-target.ipynb#ch0000006?line=67'>68</a> with torch.no_grad():
#      <a href='vscode-notebook-cell:/e%3A/Nathan/%21SKRIPSI/rl-wave/multiple-obs/model-qlearning-target.ipynb#ch0000006?line=68'>69</a>     qvals_2 = model_copy(states2)
#
# File ~\.pyenv\pyenv-win\versions\3.9.6\lib\site-packages\torch\nn\modules\module.py:727, in Module._call_impl(self, *input, **kwargs)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/modules/module.py?line=724'>725</a>     result = self._slow_forward(*input, **kwargs)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/modules/module.py?line=725'>726</a> else:
# --> <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/modules/module.py?line=726'>727</a>     result = self.forward(*input, **kwargs)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/modules/module.py?line=727'>728</a> for hook in itertools.chain(
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/modules/module.py?line=728'>729</a>         _global_forward_hooks.values(),
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/modules/module.py?line=729'>730</a>         self._forward_hooks.values()):
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/modules/module.py?line=730'>731</a>     hook_result = hook(self, input, result)
#
# File ~\.pyenv\pyenv-win\versions\3.9.6\lib\site-packages\torch\nn\modules\container.py:117, in Sequential.forward(self, input)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/modules/container.py?line=114'>115</a> def forward(self, input):
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/modules/container.py?line=115'>116</a>     for module in self:
# --> <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/modules/container.py?line=116'>117</a>         input = module(input)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/modules/container.py?line=117'>118</a>     return input
#
# File ~\.pyenv\pyenv-win\versions\3.9.6\lib\site-packages\torch\nn\modules\module.py:727, in Module._call_impl(self, *input, **kwargs)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/modules/module.py?line=724'>725</a>     result = self._slow_forward(*input, **kwargs)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/modules/module.py?line=725'>726</a> else:
# --> <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/modules/module.py?line=726'>727</a>     result = self.forward(*input, **kwargs)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/modules/module.py?line=727'>728</a> for hook in itertools.chain(
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/modules/module.py?line=728'>729</a>         _global_forward_hooks.values(),
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/modules/module.py?line=729'>730</a>         self._forward_hooks.values()):
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/modules/module.py?line=730'>731</a>     hook_result = hook(self, input, result)
#
# File ~\.pyenv\pyenv-win\versions\3.9.6\lib\site-packages\torch\nn\modules\activation.py:102, in ReLU.forward(self, input)
#     <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/modules/activation.py?line=100'>101</a> def forward(self, input: Tensor) -> Tensor:
# --> <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/modules/activation.py?line=101'>102</a>     return F.relu(input, inplace=self.inplace)
#
# File ~\.pyenv\pyenv-win\versions\3.9.6\lib\site-packages\torch\nn\functional.py:1136, in relu(input, inplace)
#    <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/functional.py?line=1133'>1134</a>     result = torch.relu_(input)
#    <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/functional.py?line=1134'>1135</a> else:
# -> <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/functional.py?line=1135'>1136</a>     result = torch.relu(input)
#    <a href='file:///c%3A/Users/USER/.pyenv/pyenv-win/versions/3.9.6/lib/site-packages/torch/nn/functional.py?line=1136'>1137</a> return result
#
# KeyboardInterrupt:

# %%
def avg_per_x_element(data, x=10):
    avg = []
    sum = 0
    for i, el in enumerate(data):
        sum += el
        if i % x == 0:
            avg.append(sum / x)
            sum = 0
    return avg

# %%
plt.plot(avg_per_x_element(losses))

# %%
plt.plot(avg_per_x_element(all_rewards))

# %%
torch.save(model.state_dict(), model_path)
print('Saved model')

# %%
def test_model(model, time_scale=3, debug=False):
    channel = EngineConfigurationChannel()
    env = UnityEnvironment(file_name='./Wave', seed=1, side_channels=[channel])
    channel.set_configuration_parameters(time_scale = time_scale)
    print("WAVE environment created.")

    env.reset()
    i = 0
    GAMMA = 0.95
    total_reward = 0
    while True:
        i += 1
        behavior_name = list(env.behavior_specs)[0]

        decision_steps, terminal_steps = env.get_steps(behavior_name)
        if (len(terminal_steps) > 0):
            break

        preds = model(torch.Tensor(preprocess_input(decision_steps))).detach().numpy()

        action = np.argmax(preds)
        action_tuple = ActionTuple()
        action_tuple.add_discrete(np.array([[action]]))
        env.set_actions(behavior_name, action_tuple)
        env.step()

        new_decision_steps, new_terminal_steps = env.get_steps(behavior_name)
        current_step = new_decision_steps if len(new_terminal_steps) == 0 else new_terminal_steps
        reward = current_step.reward[0]

        total_reward += reward

        qvals_2 = model(torch.Tensor(preprocess_input(current_step)))
        target = reward + GAMMA * ((1 - int(len(new_terminal_steps) > 0)) * torch.max(qvals_2, dim=1)[0])
        if debug:
            print(i, 'Decision Steps', preprocess_input(decision_steps), 'Preds', preds, 'Selected Preds', np.argmax(preds), 'Done?', int(len(new_terminal_steps) > 0), 'Next Preds', ((1 - int(len(new_terminal_steps) > 0)) * torch.max(qvals_2, dim=1)[0]), 'Target', target, 'Reward', reward, sep='\n')
            print('==================================')

    env.close()
    return total_reward, i

def test_model_avg(model, count=20, time_scale=10):
    sum_reward = 0
    sum_timesteps = 0
    for _ in range(count):
        reward, timesteps = test_model(model, time_scale)
        sum_timesteps += timesteps
        sum_reward += reward
    return sum / count

# %%
env.close()

# %%
test_model(model)
# Out:
# WAVE environment created.
# (38.54135325551033, 77)

# %%
test_model_avg(model)
