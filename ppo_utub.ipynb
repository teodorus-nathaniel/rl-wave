# %%
import os
import numpy as np
import torch as T
import torch.nn as nn
import torch.optim as optim
from torch.distributions.categorical import Categorical

class PPOMemory:
    def __init__(self, batch_size):
        self.states = []
        self.probs = []
        self.vals = []
        self.actions = []
        self.rewards = []
        self.dones = []

        self.batch_size = batch_size

    def generate_batches(self):
        n_states = len(self.states)
        batch_start = np.arange(0, n_states, self.batch_size)
        indices = np.arange(n_states, dtype=np.int64)
        np.random.shuffle(indices)
        batches = [indices[i:i+self.batch_size] for i in batch_start]

        return np.array(self.states),\
                np.array(self.actions),\
                np.array(self.probs),\
                np.array(self.vals),\
                np.array(self.rewards),\
                np.array(self.dones),\
                batches

    def store_memory(self, state, action, probs, vals, reward, done):
        self.states.append(state)
        self.actions.append(action)
        self.probs.append(probs)
        self.vals.append(vals)
        self.rewards.append(reward)
        self.dones.append(done)

    def clear_memory(self):
        self.states = []
        self.probs = []
        self.actions = []
        self.rewards = []
        self.dones = []
        self.vals = []

class ActorNetwork(nn.Module):
    def __init__(self, n_actions, input_dims, alpha,
            fc1_dims=512, fc2_dims=256, chkpt_dir='tmp/ppo'):
        super(ActorNetwork, self).__init__()

        self.checkpoint_file = os.path.join(chkpt_dir, 'actor_torch_ppo')
        self.actor = nn.Sequential(
                nn.Linear(*input_dims, fc1_dims),
                nn.ReLU(),
                nn.Linear(fc1_dims, fc2_dims),
                nn.ReLU(),
                nn.Linear(fc2_dims, n_actions),
                nn.Softmax(dim=-1)
        )

        self.optimizer = optim.Adam(self.parameters(), lr=alpha)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)

    def forward(self, state):
        dist = self.actor(state)
        dist = Categorical(dist)
        
        return dist

    def save_checkpoint(self):
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        self.load_state_dict(T.load(self.checkpoint_file))

class CriticNetwork(nn.Module):
    def __init__(self, input_dims, alpha, fc1_dims=512, fc2_dims=256,
            chkpt_dir='tmp/ppo'):
        super(CriticNetwork, self).__init__()

        self.checkpoint_file = os.path.join(chkpt_dir, 'critic_torch_ppo')
        self.critic = nn.Sequential(
                nn.Linear(*input_dims, fc1_dims),
                nn.ReLU(),
                nn.Linear(fc1_dims, fc2_dims),
                nn.ReLU(),
                nn.Linear(fc2_dims, 1)
        )

        self.optimizer = optim.Adam(self.parameters(), lr=alpha)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)

    def forward(self, state):
        value = self.critic(state)

        return value

    def save_checkpoint(self):
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        self.load_state_dict(T.load(self.checkpoint_file))

class Agent:
    def __init__(self, n_actions, input_dims, gamma=0.99, alpha=0.0003, gae_lambda=0.95,
            policy_clip=0.2, batch_size=64, n_epochs=10):
        self.gamma = gamma
        self.policy_clip = policy_clip
        self.n_epochs = n_epochs
        self.gae_lambda = gae_lambda

        self.actor = ActorNetwork(n_actions, input_dims, alpha)
        self.critic = CriticNetwork(input_dims, alpha)
        self.memory = PPOMemory(batch_size)
       
    def remember(self, state, action, probs, vals, reward, done):
        self.memory.store_memory(state, action, probs, vals, reward, done)

    def save_models(self):
        print('... saving models ...')
        self.actor.save_checkpoint()
        self.critic.save_checkpoint()

    def load_models(self):
        print('... loading models ...')
        self.actor.load_checkpoint()
        self.critic.load_checkpoint()

    def choose_action(self, observation):
        state = T.tensor([observation], dtype=T.float).to(self.actor.device)

        dist = self.actor(state)
        value = self.critic(state)
        action = dist.sample()

        probs = T.squeeze(dist.log_prob(action)).item()
        action = T.squeeze(action).item()
        value = T.squeeze(value).item()

        return action, probs, value

    def learn(self):
        for _ in range(self.n_epochs):
            state_arr, action_arr, old_prob_arr, vals_arr,\
            reward_arr, dones_arr, batches = \
                    self.memory.generate_batches()

            values = vals_arr
            advantage = np.zeros(len(reward_arr), dtype=np.float32)

            for t in range(len(reward_arr)-1):
                discount = 1
                a_t = 0
                for k in range(t, len(reward_arr)-1):
                    a_t += discount*(reward_arr[k] + self.gamma*values[k+1]*\
                            (1-int(dones_arr[k])) - values[k])
                    discount *= self.gamma*self.gae_lambda
                advantage[t] = a_t
            advantage = T.tensor(advantage).to(self.actor.device)

            values = T.tensor(values).to(self.actor.device)
            for batch in batches:
                states = T.tensor(state_arr[batch], dtype=T.float).to(self.actor.device)
                old_probs = T.tensor(old_prob_arr[batch]).to(self.actor.device)
                actions = T.tensor(action_arr[batch]).to(self.actor.device)

                dist = self.actor(states)
                critic_value = self.critic(states)

                critic_value = T.squeeze(critic_value)

                new_probs = dist.log_prob(actions)
                prob_ratio = new_probs.exp() / old_probs.exp()
                #prob_ratio = (new_probs - old_probs).exp()
                weighted_probs = advantage[batch] * prob_ratio
                weighted_clipped_probs = T.clamp(prob_ratio, 1-self.policy_clip,
                        1+self.policy_clip)*advantage[batch]
                actor_loss = -T.min(weighted_probs, weighted_clipped_probs).mean()

                returns = advantage[batch] + values[batch]
                critic_loss = (returns-critic_value)**2
                critic_loss = critic_loss.mean()

                total_loss = actor_loss + 0.5*critic_loss
                self.actor.optimizer.zero_grad()
                self.critic.optimizer.zero_grad()
                total_loss.backward()
                self.actor.optimizer.step()
                self.critic.optimizer.step()

        self.memory.clear_memory()

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_learning_curve(x, scores, figure_file):
    running_avg = np.zeros(len(scores))
    for i in range(len(running_avg)):
        running_avg[i] = np.mean(scores[max(0, i-100):(i+1)])
    plt.plot(x, running_avg)
    plt.title('Running average of previous 100 scores')
    plt.savefig(figure_file)

# %%
sys.path.insert(0, './common')

import gym
import numpy as np
import wave_gym_env

env_path = 'collectible/Wave'
env = wave_gym_env.CustomEnv(env_path, worker_id=34, timescale=30)
N = 1000
batch_size = 100
n_epochs = 10
alpha = 5e-4
agent = Agent(n_actions=env.action_space.n, batch_size=batch_size, 
                alpha=alpha, n_epochs=n_epochs, 
                input_dims=env.observation_space.shape)
n_games = 5000

figure_file = 'plots/wave.png'

best_score = env.reward_range[0]
score_history = []

learn_iters = 0
avg_score = 0
n_steps = 0

for i in range(n_games):
    observation = env.reset()
    done = False
    score = 0
    while not done:
        action, prob, val = agent.choose_action(observation)
        observation_, reward, done, info = env.step(action)
        n_steps += 1
        score += reward
        agent.remember(observation, action, prob, val, reward, done)
        if n_steps % N == 0:
            agent.learn()
            learn_iters += 1
        observation = observation_
    score_history.append(score)
    avg_score = np.mean(score_history[-100:])

    if avg_score > best_score:
        best_score = avg_score
        agent.save_models()

    print('episode', i, 'score %.1f' % score, 'avg score %.1f' % avg_score,
            'time_steps', n_steps, 'learning_steps', learn_iters)
x = [i+1 for i in range(len(score_history))]
plot_learning_curve(x, score_history, figure_file)
# Out:
# WAVE environment created.
# ... saving models ...
# episode 0 score -7.4 avg score -7.4 time_steps 48 learning_steps 0
# ... saving models ...
# episode 1 score -6.9 avg score -7.1 time_steps 86 learning_steps 0
# ... saving models ...
# episode 2 score -6.2 avg score -6.8 time_steps 109 learning_steps 0
# ... saving models ...
# episode 3 score 5.0 avg score -3.8 time_steps 208 learning_steps 0
# episode 4 score -6.3 avg score -4.3 time_steps 234 learning_steps 0
# episode 5 score -6.8 avg score -4.7 time_steps 270 learning_steps 0
# episode 6 score -6.3 avg score -4.9 time_steps 295 learning_steps 0
# episode 7 score -6.2 avg score -5.1 time_steps 319 learning_steps 0
# episode 8 score -6.8 avg score -5.3 time_steps 355 learning_steps 0
# episode 9 score -1.9 avg score -5.0 time_steps 494 learning_steps 0
# episode 10 score 5.0 avg score -4.0 time_steps 593 learning_steps 0
# ... saving models ...
# episode 11 score 4.4 avg score -3.3 time_steps 705 learning_steps 0
# ... saving models ...
# episode 12 score 1.3 avg score -3.0 time_steps 780 learning_steps 0
# episode 13 score -6.2 avg score -3.2 time_steps 805 learning_steps 0
# episode 14 score -7.5 avg score -3.5 time_steps 856 learning_steps 0
# episode 15 score -2.3 avg score -3.4 time_steps 902 learning_steps 0
# episode 16 score -8.2 avg score -3.7 time_steps 967 learning_steps 0
# episode 17 score 5.7 avg score -3.2 time_steps 1053 learning_steps 1
# episode 18 score -3.1 avg score -3.2 time_steps 1115 learning_steps 1
# episode 19 score -6.1 avg score -3.3 time_steps 1138 learning_steps 1
# episode 20 score 1.9 avg score -3.1 time_steps 1201 learning_steps 1
# episode 21 score -6.8 avg score -3.3 time_steps 1238 learning_steps 1
# episode 22 score 1.3 avg score -3.1 time_steps 1313 learning_steps 1
# episode 23 score -4.3 avg score -3.1 time_steps 1398 learning_steps 1
# episode 24 score -2.5 avg score -3.1 time_steps 1449 learning_steps 1
# episode 25 score -6.9 avg score -3.2 time_steps 1487 learning_steps 1
# episode 26 score -6.8 avg score -3.4 time_steps 1523 learning_steps 1
# episode 27 score -6.8 avg score -3.5 time_steps 1559 learning_steps 1
# episode 28 score -6.9 avg score -3.6 time_steps 1596 learning_steps 1
# episode 29 score -6.7 avg score -3.7 time_steps 1631 learning_steps 1
# episode 30 score -6.9 avg score -3.8 time_steps 1669 learning_steps 1
# episode 31 score -6.2 avg score -3.9 time_steps 1693 learning_steps 1
# episode 32 score -6.3 avg score -4.0 time_steps 1719 learning_steps 1
# episode 33 score -6.7 avg score -4.0 time_steps 1754 learning_steps 1
# episode 34 score -6.9 avg score -4.1 time_steps 1792 learning_steps 1
# episode 35 score -6.3 avg score -4.2 time_steps 1818 learning_steps 1
# episode 36 score -7.4 avg score -4.3 time_steps 1866 learning_steps 1
# episode 37 score -7.5 avg score -4.3 time_steps 1916 learning_steps 1
# episode 38 score -4.3 avg score -4.3 time_steps 2003 learning_steps 2
# episode 39 score -6.8 avg score -4.4 time_steps 2040 learning_steps 2
# episode 40 score -6.2 avg score -4.4 time_steps 2064 learning_steps 2
# episode 41 score 3.2 avg score -4.3 time_steps 2200 learning_steps 2
# episode 42 score 2.5 avg score -4.1 time_steps 2351 learning_steps 2
# episode 43 score -6.3 avg score -4.2 time_steps 2376 learning_steps 2
# episode 44 score -7.5 avg score -4.2 time_steps 2426 learning_steps 2
# episode 45 score 6.4 avg score -4.0 time_steps 2499 learning_steps 2
# episode 46 score -7.5 avg score -4.1 time_steps 2549 learning_steps 2
# episode 47 score -6.3 avg score -4.1 time_steps 2575 learning_steps 2
# episode 48 score -7.3 avg score -4.2 time_steps 2622 learning_steps 2
# episode 49 score -7.4 avg score -4.3 time_steps 2671 learning_steps 2
# episode 50 score -3.1 avg score -4.2 time_steps 2734 learning_steps 2
# episode 51 score -6.9 avg score -4.3 time_steps 2772 learning_steps 2
# episode 52 score -2.5 avg score -4.2 time_steps 2822 learning_steps 2
# episode 53 score -8.0 avg score -4.3 time_steps 2882 learning_steps 2
# episode 54 score -3.2 avg score -4.3 time_steps 2946 learning_steps 2
# episode 55 score -1.8 avg score -4.3 time_steps 2982 learning_steps 2
# episode 56 score -2.5 avg score -4.2 time_steps 3032 learning_steps 3
# episode 57 score -8.7 avg score -4.3 time_steps 3107 learning_steps 3
# episode 58 score -4.4 avg score -4.3 time_steps 3195 learning_steps 3
# episode 59 score -6.9 avg score -4.3 time_steps 3232 learning_steps 3
# episode 60 score 3.2 avg score -4.2 time_steps 3367 learning_steps 3
# episode 61 score -6.2 avg score -4.2 time_steps 3391 learning_steps 3
# episode 62 score -4.3 avg score -4.3 time_steps 3478 learning_steps 3
# episode 63 score -6.8 avg score -4.3 time_steps 3514 learning_steps 3
# episode 64 score 8.8 avg score -4.1 time_steps 3639 learning_steps 3
# episode 65 score 12.5 avg score -3.8 time_steps 3789 learning_steps 3
# episode 66 score -3.1 avg score -3.8 time_steps 3852 learning_steps 3
# episode 67 score -6.7 avg score -3.9 time_steps 3887 learning_steps 3
# episode 68 score 11.2 avg score -3.7 time_steps 4063 learning_steps 4
# episode 69 score -6.2 avg score -3.7 time_steps 4088 learning_steps 4
# episode 70 score 6.3 avg score -3.5 time_steps 4162 learning_steps 4
# episode 71 score -6.2 avg score -3.6 time_steps 4187 learning_steps 4
# episode 72 score -6.2 avg score -3.6 time_steps 4210 learning_steps 4
# episode 73 score 6.2 avg score -3.5 time_steps 4286 learning_steps 4
# episode 74 score -6.2 avg score -3.5 time_steps 4311 learning_steps 4
# episode 75 score -6.2 avg score -3.6 time_steps 4334 learning_steps 4
# episode 76 score 0.7 avg score -3.5 time_steps 4421 learning_steps 4
# episode 77 score -6.2 avg score -3.5 time_steps 4446 learning_steps 4
# episode 78 score -3.0 avg score -3.5 time_steps 4507 learning_steps 4
# episode 79 score -1.9 avg score -3.5 time_steps 4545 learning_steps 4
# episode 80 score 8.1 avg score -3.4 time_steps 4683 learning_steps 4
# episode 81 score -6.2 avg score -3.4 time_steps 4707 learning_steps 4
# episode 82 score 1.9 avg score -3.3 time_steps 4770 learning_steps 4
# episode 83 score -6.8 avg score -3.4 time_steps 4805 learning_steps 4
# episode 84 score -6.8 avg score -3.4 time_steps 4842 learning_steps 4
# episode 85 score -6.3 avg score -3.5 time_steps 4867 learning_steps 4
# episode 86 score -9.2 avg score -3.5 time_steps 4952 learning_steps 4
# episode 87 score -1.9 avg score -3.5 time_steps 4990 learning_steps 4
# episode 88 score 5.1 avg score -3.4 time_steps 5089 learning_steps 5
# episode 89 score -7.5 avg score -3.4 time_steps 5138 learning_steps 5
# episode 90 score 0.6 avg score -3.4 time_steps 5226 learning_steps 5
# episode 91 score -6.1 avg score -3.4 time_steps 5249 learning_steps 5
# episode 92 score 13.7 avg score -3.2 time_steps 5374 learning_steps 5
# episode 93 score -6.3 avg score -3.3 time_steps 5400 learning_steps 5
# episode 94 score -6.8 avg score -3.3 time_steps 5436 learning_steps 5
# episode 95 score -6.1 avg score -3.3 time_steps 5458 learning_steps 5
# episode 96 score 1.2 avg score -3.3 time_steps 5534 learning_steps 5
# episode 97 score -6.2 avg score -3.3 time_steps 5558 learning_steps 5
# episode 98 score 5.6 avg score -3.2 time_steps 5646 learning_steps 5
# episode 99 score -2.5 avg score -3.2 time_steps 5697 learning_steps 5
# episode 100 score -6.1 avg score -3.2 time_steps 5719 learning_steps 5
# ... saving models ...
# episode 101 score 16.9 avg score -3.0 time_steps 5882 learning_steps 5
# episode 102 score -6.9 avg score -3.0 time_steps 5920 learning_steps 5
# episode 103 score -6.2 avg score -3.1 time_steps 5945 learning_steps 5
# episode 104 score -6.7 avg score -3.1 time_steps 5980 learning_steps 5
# ... saving models ...
# episode 105 score 8.1 avg score -3.0 time_steps 6118 learning_steps 6
# episode 106 score -10.6 avg score -3.0 time_steps 6231 learning_steps 6
# ... saving models ...
# episode 107 score 4.4 avg score -2.9 time_steps 6442 learning_steps 6
# ... saving models ...
# episode 108 score 8.0 avg score -2.7 time_steps 6781 learning_steps 6
# episode 109 score -7.5 avg score -2.8 time_steps 6831 learning_steps 6
# episode 110 score 3.8 avg score -2.8 time_steps 6956 learning_steps 6
# episode 111 score -7.5 avg score -2.9 time_steps 7006 learning_steps 7
# episode 112 score 0.0 avg score -2.9 time_steps 7106 learning_steps 7
# ... saving models ...
# episode 113 score 31.9 avg score -2.6 time_steps 7369 learning_steps 7
# ... saving models ...
# episode 114 score 24.4 avg score -2.2 time_steps 7582 learning_steps 7
# ... saving models ...
# episode 115 score 1.3 avg score -2.2 time_steps 7656 learning_steps 7
# ... saving models ...
# episode 116 score -7.5 avg score -2.2 time_steps 7705 learning_steps 7
# ... saving models ...
# episode 117 score 16.2 avg score -2.1 time_steps 7980 learning_steps 7
# episode 118 score -6.9 avg score -2.1 time_steps 8018 learning_steps 8
# ... saving models ...
# episode 119 score 6.3 avg score -2.0 time_steps 8092 learning_steps 8
# ... saving models ...
# episode 120 score 19.4 avg score -1.8 time_steps 8305 learning_steps 8
# ... saving models ...
# episode 121 score 91.8 avg score -0.8 time_steps 8869 learning_steps 8
# episode 122 score -5.0 avg score -0.9 time_steps 9070 learning_steps 9
# ... saving models ...
# episode 123 score 13.8 avg score -0.7 time_steps 9195 learning_steps 9
# episode 124 score -6.2 avg score -0.8 time_steps 9219 learning_steps 9
# ... saving models ...
# episode 125 score 88.7 avg score 0.2 time_steps 9846 learning_steps 9
# ... saving models ...
# episode 126 score -6.2 avg score 0.2 time_steps 9870 learning_steps 9
# ... saving models ...
# episode 127 score 12.4 avg score 0.4 time_steps 10121 learning_steps 10
# ... saving models ...
# episode 128 score 27.5 avg score 0.7 time_steps 10371 learning_steps 10
# episode 129 score -7.5 avg score 0.7 time_steps 10420 learning_steps 10
# ... saving models ...
# episode 130 score 58.7 avg score 1.4 time_steps 10847 learning_steps 10
# ... saving models ...
# episode 131 score -6.2 avg score 1.4 time_steps 10871 learning_steps 10
# ... saving models ...
# episode 132 score -6.1 avg score 1.4 time_steps 10894 learning_steps 10
# ... saving models ...
# episode 133 score 6.2 avg score 1.5 time_steps 10970 learning_steps 10
# ... saving models ...
# episode 134 score 24.3 avg score 1.8 time_steps 11185 learning_steps 11
# ... saving models ...
# episode 135 score -6.1 avg score 1.8 time_steps 11208 learning_steps 11
# ... saving models ...
# episode 136 score 9.4 avg score 2.0 time_steps 11319 learning_steps 11
# ... saving models ...
# episode 137 score -5.0 avg score 2.0 time_steps 11419 learning_steps 11
# ... saving models ...
# episode 138 score -1.3 avg score 2.0 time_steps 11544 learning_steps 11
# ... saving models ...
# episode 139 score 8.1 avg score 2.2 time_steps 11683 learning_steps 11
# ... saving models ...
# episode 140 score -6.1 avg score 2.2 time_steps 11705 learning_steps 11
# ... saving models ...
# episode 141 score 10.6 avg score 2.3 time_steps 11793 learning_steps 11
# ... saving models ...
# episode 142 score 8.1 avg score 2.3 time_steps 12031 learning_steps 12
# ... saving models ...
# episode 143 score -6.1 avg score 2.3 time_steps 12054 learning_steps 12
# ... saving models ...
# episode 144 score 5.6 avg score 2.5 time_steps 12143 learning_steps 12
# ... saving models ...
# episode 145 score 29.4 avg score 2.7 time_steps 12455 learning_steps 12
# ... saving models ...
# episode 146 score -6.2 avg score 2.7 time_steps 12479 learning_steps 12
# ... saving models ...
# episode 147 score -6.2 avg score 2.7 time_steps 12503 learning_steps 12
# ... saving models ...
# episode 148 score 33.1 avg score 3.1 time_steps 12741 learning_steps 12
# ... saving models ...
# episode 149 score -6.2 avg score 3.1 time_steps 12765 learning_steps 12
# episode 150 score -6.2 avg score 3.1 time_steps 12789 learning_steps 12
# ... saving models ...
# episode 151 score 29.2 avg score 3.5 time_steps 13105 learning_steps 13
# episode 152 score -6.1 avg score 3.4 time_steps 13127 learning_steps 13
# ... saving models ...
# episode 153 score 11.3 avg score 3.6 time_steps 13202 learning_steps 13
# episode 154 score -6.1 avg score 3.6 time_steps 13224 learning_steps 13
# ... saving models ...
# episode 155 score 16.2 avg score 3.8 time_steps 13401 learning_steps 13
# episode 156 score -6.8 avg score 3.7 time_steps 13438 learning_steps 13
# ... saving models ...
# episode 157 score 27.5 avg score 4.1 time_steps 13789 learning_steps 13
# ... saving models ...
# episode 158 score -2.4 avg score 4.1 time_steps 13837 learning_steps 13
# ... saving models ...
# episode 159 score 259.7 avg score 6.8 time_steps 14943 learning_steps 14
# episode 160 score -6.2 avg score 6.7 time_steps 14968 learning_steps 14
# ... saving models ...
# episode 161 score 42.5 avg score 7.2 time_steps 15218 learning_steps 15
# episode 162 score -6.3 avg score 7.1 time_steps 15244 learning_steps 15
# ... saving models ...
# episode 163 score 10.1 avg score 7.3 time_steps 15343 learning_steps 15
# ... saving models ...
# episode 164 score 50.6 avg score 7.7 time_steps 15732 learning_steps 15
# episode 165 score -9.9 avg score 7.5 time_steps 15831 learning_steps 15
# episode 166 score 6.2 avg score 7.6 time_steps 15907 learning_steps 15
# ... saving models ...
# episode 167 score 46.8 avg score 8.1 time_steps 16171 learning_steps 16
# ... saving models ...
# episode 168 score 116.8 avg score 9.2 time_steps 16836 learning_steps 16
# episode 169 score -7.5 avg score 9.2 time_steps 16886 learning_steps 16
# episode 170 score -6.8 avg score 9.0 time_steps 16923 learning_steps 16
# ... saving models ...
# episode 171 score 117.3 avg score 10.3 time_steps 17577 learning_steps 17
# episode 172 score -9.9 avg score 10.2 time_steps 17675 learning_steps 17
# ... saving models ...
# episode 173 score 83.7 avg score 11.0 time_steps 18301 learning_steps 18
# ... saving models ...
# episode 174 score 11.2 avg score 11.2 time_steps 18478 learning_steps 18
# ... saving models ...
# episode 175 score -0.6 avg score 11.2 time_steps 18590 learning_steps 18
# episode 176 score -0.5 avg score 11.2 time_steps 18701 learning_steps 18
# ... saving models ...
# episode 177 score 42.5 avg score 11.7 time_steps 18952 learning_steps 18
# ... saving models ...
# episode 178 score 154.8 avg score 13.3 time_steps 19856 learning_steps 19
# ... saving models ...
# episode 179 score 24.9 avg score 13.6 time_steps 20058 learning_steps 20
# episode 180 score 6.9 avg score 13.6 time_steps 20120 learning_steps 20
# ... saving models ...
# episode 181 score 148.7 avg score 15.1 time_steps 20747 learning_steps 20
# episode 182 score 1.9 avg score 15.1 time_steps 20910 learning_steps 20
# ... saving models ...
# episode 183 score 60.7 avg score 15.8 time_steps 21397 learning_steps 21
# ... saving models ...
# episode 184 score 139.8 avg score 17.2 time_steps 22201 learning_steps 22
# ... saving models ...
# episode 185 score 21.2 avg score 17.5 time_steps 22378 learning_steps 22
# ... saving models ...
# episode 186 score 36.2 avg score 18.0 time_steps 22554 learning_steps 22
# ... saving models ...
# episode 187 score 5.1 avg score 18.0 time_steps 22652 learning_steps 22
# ... saving models ...
# episode 188 score 58.7 avg score 18.6 time_steps 22978 learning_steps 22
# ... saving models ...
# episode 189 score 5.0 avg score 18.7 time_steps 23078 learning_steps 23
# episode 190 score 0.0 avg score 18.7 time_steps 23178 learning_steps 23
# ... saving models ...
# episode 191 score 84.3 avg score 19.6 time_steps 23592 learning_steps 23
# ... saving models ...
# episode 192 score 22.5 avg score 19.7 time_steps 23843 learning_steps 23
# episode 193 score -9.9 avg score 19.6 time_steps 23942 learning_steps 23
# episode 194 score -6.2 avg score 19.7 time_steps 23966 learning_steps 23
# ... saving models ...
# episode 195 score 2.5 avg score 19.7 time_steps 24016 learning_steps 24
# ... saving models ...
# episode 196 score 5.0 avg score 19.8 time_steps 24116 learning_steps 24
# episode 197 score -6.2 avg score 19.8 time_steps 24140 learning_steps 24
# episode 198 score 5.1 avg score 19.8 time_steps 24239 learning_steps 24
# episode 199 score -6.2 avg score 19.7 time_steps 24263 learning_steps 24
# episode 200 score -6.2 avg score 19.7 time_steps 24286 learning_steps 24
# episode 201 score 18.7 avg score 19.8 time_steps 24413 learning_steps 24
# ... saving models ...
# episode 202 score 108.7 avg score 20.9 time_steps 24939 learning_steps 24
# ... saving models ...
# episode 203 score 100.5 avg score 22.0 time_steps 25429 learning_steps 25
# ... saving models ...
# episode 204 score 138.7 avg score 23.4 time_steps 26055 learning_steps 26
# ... saving models ...
# episode 205 score 35.6 avg score 23.7 time_steps 26244 learning_steps 26
# ... saving models ...
# episode 206 score -6.2 avg score 23.8 time_steps 26268 learning_steps 26
# episode 207 score -6.9 avg score 23.6 time_steps 26305 learning_steps 26
# ... saving models ...
# episode 208 score 171.2 avg score 25.3 time_steps 26982 learning_steps 26
# episode 209 score -10.0 avg score 25.2 time_steps 27083 learning_steps 27
# episode 210 score 5.0 avg score 25.3 time_steps 27184 learning_steps 27
# ... saving models ...
# episode 211 score 19.5 avg score 25.5 time_steps 27295 learning_steps 27
# ... saving models ...
# episode 212 score 20.0 avg score 25.7 time_steps 27496 learning_steps 27
# episode 213 score -6.8 avg score 25.3 time_steps 27531 learning_steps 27
# episode 214 score 19.3 avg score 25.3 time_steps 27745 learning_steps 27
# episode 215 score -6.2 avg score 25.2 time_steps 27769 learning_steps 27
# episode 216 score 30.6 avg score 25.6 time_steps 27957 learning_steps 27
# ... saving models ...
# episode 217 score 69.3 avg score 26.1 time_steps 28371 learning_steps 28
# ... saving models ...
# episode 218 score -6.2 avg score 26.1 time_steps 28395 learning_steps 28
# episode 219 score -6.8 avg score 26.0 time_steps 28430 learning_steps 28
# episode 220 score 1.8 avg score 25.8 time_steps 28494 learning_steps 28
# episode 221 score 11.3 avg score 25.0 time_steps 28569 learning_steps 28
# episode 222 score 15.0 avg score 25.2 time_steps 28670 learning_steps 28
# episode 223 score -6.1 avg score 25.0 time_steps 28693 learning_steps 28
# episode 224 score -10.0 avg score 25.0 time_steps 28794 learning_steps 28
# episode 225 score -6.1 avg score 24.0 time_steps 28816 learning_steps 28
# episode 226 score 27.4 avg score 24.4 time_steps 28968 learning_steps 28
# episode 227 score -6.2 avg score 24.2 time_steps 28992 learning_steps 28
# episode 228 score -6.1 avg score 23.8 time_steps 29015 learning_steps 29
# episode 229 score 51.2 avg score 24.4 time_steps 29292 learning_steps 29
# episode 230 score -6.8 avg score 23.8 time_steps 29329 learning_steps 29
# episode 231 score 26.2 avg score 24.1 time_steps 29505 learning_steps 29
# episode 232 score 68.7 avg score 24.9 time_steps 29931 learning_steps 29
# episode 233 score -9.3 avg score 24.7 time_steps 30018 learning_steps 30
# episode 234 score -6.2 avg score 24.4 time_steps 30042 learning_steps 30
# episode 235 score 28.2 avg score 24.7 time_steps 30279 learning_steps 30
# episode 236 score -6.2 avg score 24.6 time_steps 30304 learning_steps 30
# episode 237 score 1.3 avg score 24.6 time_steps 30378 learning_steps 30
# episode 238 score -2.5 avg score 24.6 time_steps 30429 learning_steps 30
# episode 239 score -6.2 avg score 24.5 time_steps 30453 learning_steps 30
# episode 240 score -6.1 avg score 24.5 time_steps 30476 learning_steps 30
# episode 241 score 9.4 avg score 24.5 time_steps 30588 learning_steps 30
# episode 242 score -6.9 avg score 24.3 time_steps 30626 learning_steps 30
# episode 243 score 15.7 avg score 24.5 time_steps 30712 learning_steps 30
# episode 244 score 50.5 avg score 25.0 time_steps 31002 learning_steps 31
# episode 245 score -6.8 avg score 24.6 time_steps 31038 learning_steps 31
# episode 246 score -2.5 avg score 24.7 time_steps 31088 learning_steps 31
# episode 247 score 12.5 avg score 24.9 time_steps 31238 learning_steps 31
# episode 248 score -0.6 avg score 24.5 time_steps 31350 learning_steps 31
# episode 249 score 1.9 avg score 24.6 time_steps 31412 learning_steps 31
# episode 250 score 80.0 avg score 25.5 time_steps 31813 learning_steps 31
# episode 251 score -6.2 avg score 25.1 time_steps 31836 learning_steps 31
# ... saving models ...
# episode 252 score 133.0 avg score 26.5 time_steps 32477 learning_steps 32
# ... saving models ...
# episode 253 score 51.2 avg score 26.9 time_steps 32853 learning_steps 32
# episode 254 score -6.7 avg score 26.9 time_steps 32888 learning_steps 32
# episode 255 score 1.3 avg score 26.7 time_steps 32962 learning_steps 32
# episode 256 score -6.9 avg score 26.7 time_steps 33001 learning_steps 33
# episode 257 score 4.4 avg score 26.5 time_steps 33113 learning_steps 33
# episode 258 score -6.8 avg score 26.5 time_steps 33150 learning_steps 33
# episode 259 score 162.3 avg score 25.5 time_steps 34004 learning_steps 34
# episode 260 score 6.3 avg score 25.6 time_steps 34078 learning_steps 34
# episode 261 score 27.5 avg score 25.5 time_steps 34229 learning_steps 34
# episode 262 score 42.5 avg score 26.0 time_steps 34479 learning_steps 34
# episode 263 score -6.2 avg score 25.8 time_steps 34504 learning_steps 34
# episode 264 score 102.4 avg score 26.3 time_steps 35055 learning_steps 35
# episode 265 score 48.1 avg score 26.9 time_steps 35293 learning_steps 35
# episode 266 score -5.0 avg score 26.8 time_steps 35394 learning_steps 35
# episode 267 score 20.1 avg score 26.5 time_steps 35592 learning_steps 35
# episode 268 score 107.9 avg score 26.4 time_steps 36234 learning_steps 36
# episode 269 score -6.1 avg score 26.4 time_steps 36257 learning_steps 36
# episode 270 score 10.6 avg score 26.6 time_steps 36345 learning_steps 36
# episode 271 score 15.0 avg score 25.6 time_steps 36445 learning_steps 36
# episode 272 score -6.3 avg score 25.6 time_steps 36471 learning_steps 36
# episode 273 score 25.7 avg score 25.0 time_steps 36657 learning_steps 36
# episode 274 score 6.2 avg score 25.0 time_steps 36732 learning_steps 36
# episode 275 score 52.5 avg score 25.5 time_steps 36982 learning_steps 36
# ... saving models ...
# episode 276 score 152.3 avg score 27.1 time_steps 37835 learning_steps 37
# episode 277 score -6.8 avg score 26.6 time_steps 37872 learning_steps 37
# episode 278 score 17.5 avg score 25.2 time_steps 38022 learning_steps 38
# episode 279 score -6.2 avg score 24.9 time_steps 38046 learning_steps 38
# episode 280 score -6.2 avg score 24.7 time_steps 38071 learning_steps 38
# episode 281 score 5.6 avg score 23.3 time_steps 38159 learning_steps 38
# episode 282 score 31.3 avg score 23.6 time_steps 38334 learning_steps 38
# episode 283 score -6.1 avg score 22.9 time_steps 38357 learning_steps 38
# episode 284 score 27.5 avg score 21.8 time_steps 38507 learning_steps 38
# episode 285 score 53.8 avg score 22.1 time_steps 38732 learning_steps 38
# episode 286 score -6.3 avg score 21.7 time_steps 38758 learning_steps 38
# episode 287 score -6.8 avg score 21.6 time_steps 38795 learning_steps 38
# episode 288 score 56.8 avg score 21.6 time_steps 39059 learning_steps 39
# episode 289 score 0.1 avg score 21.5 time_steps 39158 learning_steps 39
# episode 290 score 6.2 avg score 21.6 time_steps 39233 learning_steps 39
# episode 291 score 6.3 avg score 20.8 time_steps 39307 learning_steps 39
# episode 292 score 2.6 avg score 20.6 time_steps 39356 learning_steps 39
# episode 293 score 78.7 avg score 21.5 time_steps 39683 learning_steps 39
# episode 294 score 91.2 avg score 22.5 time_steps 40159 learning_steps 40
# episode 295 score -8.8 avg score 22.4 time_steps 40235 learning_steps 40
# episode 296 score 57.5 avg score 22.9 time_steps 40586 learning_steps 40
# episode 297 score 60.0 avg score 23.5 time_steps 40987 learning_steps 40
# episode 298 score 152.5 avg score 25.0 time_steps 41738 learning_steps 41
# episode 299 score 60.4 avg score 25.7 time_steps 42130 learning_steps 42
# episode 300 score -6.7 avg score 25.7 time_steps 42164 learning_steps 42
# episode 301 score 92.4 avg score 26.4 time_steps 42615 learning_steps 42
# episode 302 score 6.8 avg score 25.4 time_steps 42779 learning_steps 42
# episode 303 score 31.9 avg score 24.7 time_steps 43042 learning_steps 43
# episode 304 score -6.2 avg score 23.3 time_steps 43067 learning_steps 43
# episode 305 score 118.1 avg score 24.1 time_steps 43605 learning_steps 43
# episode 306 score 48.6 avg score 24.6 time_steps 43933 learning_steps 43
# episode 307 score 75.0 avg score 25.5 time_steps 44334 learning_steps 44
# episode 308 score 11.3 avg score 23.9 time_steps 44508 learning_steps 44
# episode 309 score 37.4 avg score 24.3 time_steps 44760 learning_steps 44
# episode 310 score -6.2 avg score 24.2 time_steps 44783 learning_steps 44
# episode 311 score -0.5 avg score 24.0 time_steps 44894 learning_steps 44
# episode 312 score 116.1 avg score 25.0 time_steps 45473 learning_steps 45
# episode 313 score 5.0 avg score 25.1 time_steps 45573 learning_steps 45
# episode 314 score 10.6 avg score 25.0 time_steps 45661 learning_steps 45
# episode 315 score 132.4 avg score 26.4 time_steps 46414 learning_steps 46
# episode 316 score 80.5 avg score 26.9 time_steps 46904 learning_steps 46
# episode 317 score 26.8 avg score 26.5 time_steps 47168 learning_steps 47
# episode 318 score -6.2 avg score 26.5 time_steps 47192 learning_steps 47
# episode 319 score 17.0 avg score 26.7 time_steps 47353 learning_steps 47
# ... saving models ...
# episode 320 score 231.6 avg score 29.0 time_steps 48622 learning_steps 48
# ... saving models ...
# episode 321 score 82.4 avg score 29.7 time_steps 49175 learning_steps 49
# episode 322 score -3.7 avg score 29.5 time_steps 49350 learning_steps 49
# ... saving models ...
# episode 323 score 171.7 avg score 31.3 time_steps 50216 learning_steps 50
# ... saving models ...
# episode 324 score -6.2 avg score 31.3 time_steps 50240 learning_steps 50
# ... saving models ...
# episode 325 score 5.0 avg score 31.5 time_steps 50339 learning_steps 50
# ... saving models ...
# episode 326 score 127.3 avg score 32.5 time_steps 50993 learning_steps 50
# episode 327 score -8.7 avg score 32.4 time_steps 51068 learning_steps 51
# ... saving models ...
# episode 328 score 15.6 avg score 32.7 time_steps 51155 learning_steps 51
# episode 329 score 45.6 avg score 32.6 time_steps 51443 learning_steps 51
# ... saving models ...
# episode 330 score 30.0 avg score 33.0 time_steps 51743 learning_steps 51
# episode 331 score -7.5 avg score 32.6 time_steps 51793 learning_steps 51
# episode 332 score 81.8 avg score 32.8 time_steps 52157 learning_steps 52
# episode 333 score -6.2 avg score 32.8 time_steps 52181 learning_steps 52
# ... saving models ...
# episode 334 score 36.8 avg score 33.2 time_steps 52445 learning_steps 52
# episode 335 score 5.7 avg score 33.0 time_steps 52532 learning_steps 52
# episode 336 score 5.7 avg score 33.1 time_steps 52618 learning_steps 52
# ... saving models ...
# episode 337 score 14.3 avg score 33.2 time_steps 52732 learning_steps 52
# episode 338 score -6.2 avg score 33.2 time_steps 52756 learning_steps 52
# ... saving models ...
# episode 339 score 10.1 avg score 33.4 time_steps 52854 learning_steps 52
# episode 340 score -6.8 avg score 33.4 time_steps 52891 learning_steps 52
# episode 341 score -6.3 avg score 33.2 time_steps 52916 learning_steps 52
# episode 342 score -6.2 avg score 33.2 time_steps 52941 learning_steps 52
# episode 343 score -6.8 avg score 33.0 time_steps 52977 learning_steps 52
# episode 344 score 21.2 avg score 32.7 time_steps 53153 learning_steps 53
# episode 345 score 9.4 avg score 32.9 time_steps 53265 learning_steps 53
# episode 346 score 14.5 avg score 33.0 time_steps 53376 learning_steps 53
# episode 347 score -6.3 avg score 32.8 time_steps 53401 learning_steps 53
# episode 348 score -6.2 avg score 32.8 time_steps 53426 learning_steps 53
# episode 349 score 14.4 avg score 32.9 time_steps 53538 learning_steps 53
# episode 350 score 5.0 avg score 32.2 time_steps 53638 learning_steps 53
# episode 351 score 2.5 avg score 32.2 time_steps 53688 learning_steps 53
# episode 352 score 4.5 avg score 31.0 time_steps 53799 learning_steps 53
# episode 353 score 1.9 avg score 30.5 time_steps 53861 learning_steps 53
# episode 354 score 18.8 avg score 30.7 time_steps 53986 learning_steps 53
# episode 355 score 13.7 avg score 30.8 time_steps 54113 learning_steps 54
# episode 356 score 14.5 avg score 31.1 time_steps 54224 learning_steps 54
# episode 357 score 5.0 avg score 31.1 time_steps 54325 learning_steps 54
# episode 358 score 16.9 avg score 31.3 time_steps 54487 learning_steps 54
# episode 359 score -6.2 avg score 29.6 time_steps 54511 learning_steps 54
# episode 360 score -6.2 avg score 29.5 time_steps 54536 learning_steps 54
# episode 361 score 32.6 avg score 29.5 time_steps 54685 learning_steps 54
# episode 362 score 102.4 avg score 30.1 time_steps 55237 learning_steps 55
# episode 363 score 37.4 avg score 30.6 time_steps 55489 learning_steps 55
# episode 364 score -6.2 avg score 29.5 time_steps 55513 learning_steps 55
# episode 365 score 53.8 avg score 29.6 time_steps 55737 learning_steps 55
# episode 366 score 46.8 avg score 30.1 time_steps 56001 learning_steps 56
# episode 367 score 96.1 avg score 30.8 time_steps 56579 learning_steps 56
# episode 368 score 14.4 avg score 29.9 time_steps 56692 learning_steps 56
# episode 369 score 29.4 avg score 30.2 time_steps 56905 learning_steps 56
# episode 370 score -6.2 avg score 30.1 time_steps 56929 learning_steps 56
# episode 371 score 51.9 avg score 30.4 time_steps 57191 learning_steps 57
# episode 372 score 64.9 avg score 31.2 time_steps 57594 learning_steps 57
# episode 373 score 2.6 avg score 30.9 time_steps 57742 learning_steps 57
# episode 374 score -6.3 avg score 30.8 time_steps 57769 learning_steps 57
# episode 375 score 1.3 avg score 30.3 time_steps 57943 learning_steps 57
# episode 376 score 5.1 avg score 28.8 time_steps 58041 learning_steps 58
# episode 377 score 59.3 avg score 29.5 time_steps 58355 learning_steps 58
# episode 378 score -8.1 avg score 29.2 time_steps 58417 learning_steps 58
# episode 379 score -2.5 avg score 29.3 time_steps 58468 learning_steps 58
# episode 380 score 81.8 avg score 30.1 time_steps 59032 learning_steps 59
# episode 381 score 40.0 avg score 30.5 time_steps 59333 learning_steps 59
# episode 382 score -2.4 avg score 30.1 time_steps 59481 learning_steps 59
# episode 383 score 23.1 avg score 30.4 time_steps 59619 learning_steps 59
# episode 384 score 4.9 avg score 30.2 time_steps 59720 learning_steps 59
# episode 385 score 4.5 avg score 29.7 time_steps 59830 learning_steps 59
# episode 386 score 6.3 avg score 29.8 time_steps 59905 learning_steps 59
# episode 387 score 30.6 avg score 30.2 time_steps 60092 learning_steps 60
# episode 388 score 60.5 avg score 30.3 time_steps 60382 learning_steps 60
# episode 389 score 18.1 avg score 30.4 time_steps 60620 learning_steps 60
# episode 390 score -6.1 avg score 30.3 time_steps 60643 learning_steps 60
# episode 391 score 31.2 avg score 30.6 time_steps 60820 learning_steps 60
# episode 392 score 0.7 avg score 30.5 time_steps 60907 learning_steps 60
# episode 393 score 5.1 avg score 29.8 time_steps 61005 learning_steps 61
# episode 394 score 230.4 avg score 31.2 time_steps 62197 learning_steps 62
# episode 395 score -10.1 avg score 31.2 time_steps 62299 learning_steps 62
# episode 396 score 212.3 avg score 32.7 time_steps 63153 learning_steps 63
# episode 397 score -1.9 avg score 32.1 time_steps 63292 learning_steps 63
# episode 398 score 191.8 avg score 32.5 time_steps 64157 learning_steps 64
# ... saving models ...
# episode 399 score 161.7 avg score 33.5 time_steps 64923 learning_steps 64
# ... saving models ...
# episode 400 score 13.1 avg score 33.7 time_steps 65161 learning_steps 65
# episode 401 score -6.2 avg score 32.7 time_steps 65185 learning_steps 65
# episode 402 score 32.6 avg score 33.0 time_steps 65434 learning_steps 65
# episode 403 score 87.4 avg score 33.5 time_steps 65887 learning_steps 65
# ... saving models ...
# episode 404 score 117.4 avg score 34.8 time_steps 66440 learning_steps 66
# episode 405 score 11.3 avg score 33.7 time_steps 66615 learning_steps 66
# episode 406 score 35.0 avg score 33.6 time_steps 66815 learning_steps 66
# episode 407 score 116.2 avg score 34.0 time_steps 67392 learning_steps 67
# episode 408 score -10.0 avg score 33.8 time_steps 67492 learning_steps 67
# episode 409 score 10.0 avg score 33.5 time_steps 67592 learning_steps 67
# episode 410 score 101.2 avg score 34.6 time_steps 68069 learning_steps 68
# ... saving models ...
# episode 411 score 254.8 avg score 37.1 time_steps 69073 learning_steps 69
# episode 412 score 68.8 avg score 36.7 time_steps 69398 learning_steps 69
# episode 413 score 27.4 avg score 36.9 time_steps 69650 learning_steps 69
# episode 414 score 11.3 avg score 36.9 time_steps 69825 learning_steps 69
# episode 415 score 98.6 avg score 36.6 time_steps 70453 learning_steps 70
# episode 416 score -8.7 avg score 35.7 time_steps 70527 learning_steps 70
# episode 417 score 26.9 avg score 35.7 time_steps 70690 learning_steps 70
# episode 418 score 0.1 avg score 35.7 time_steps 70789 learning_steps 70
# episode 419 score -6.2 avg score 35.5 time_steps 70814 learning_steps 70
# episode 420 score -6.2 avg score 33.1 time_steps 70838 learning_steps 70
# episode 421 score 58.7 avg score 32.9 time_steps 71164 learning_steps 71
# episode 422 score 110.5 avg score 34.0 time_steps 71854 learning_steps 71
# episode 423 score 18.1 avg score 32.5 time_steps 72093 learning_steps 72
# episode 424 score 30.0 avg score 32.8 time_steps 72294 learning_steps 72
# episode 425 score 6.9 avg score 32.9 time_steps 72457 learning_steps 72
# episode 426 score -6.2 avg score 31.5 time_steps 72480 learning_steps 72
# episode 427 score 211.2 avg score 33.7 time_steps 73457 learning_steps 73
# episode 428 score 16.1 avg score 33.7 time_steps 73735 learning_steps 73
# episode 429 score 32.5 avg score 33.6 time_steps 73986 learning_steps 73
# episode 430 score -6.8 avg score 33.2 time_steps 74023 learning_steps 74
# episode 431 score 89.9 avg score 34.2 time_steps 74625 learning_steps 74
# episode 432 score -1.9 avg score 33.4 time_steps 74762 learning_steps 74
# episode 433 score 5.0 avg score 33.5 time_steps 74862 learning_steps 74
# episode 434 score -6.2 avg score 33.1 time_steps 74887 learning_steps 74
# episode 435 score 103.1 avg score 34.0 time_steps 75325 learning_steps 75
# episode 436 score 31.2 avg score 34.3 time_steps 75602 learning_steps 75
# episode 437 score 103.6 avg score 35.2 time_steps 76230 learning_steps 76
# episode 438 score -7.5 avg score 35.2 time_steps 76279 learning_steps 76
# episode 439 score -6.1 avg score 35.0 time_steps 76302 learning_steps 76
# episode 440 score 6.8 avg score 35.1 time_steps 76366 learning_steps 76
# episode 441 score 2.0 avg score 35.2 time_steps 76426 learning_steps 76
# episode 442 score 57.4 avg score 35.9 time_steps 76679 learning_steps 76
# episode 443 score -6.2 avg score 35.9 time_steps 76703 learning_steps 76
# episode 444 score 68.1 avg score 36.3 time_steps 77041 learning_steps 77
# episode 445 score 0.1 avg score 36.2 time_steps 77140 learning_steps 77
# episode 446 score -6.2 avg score 36.0 time_steps 77163 learning_steps 77
# episode 447 score -6.3 avg score 36.0 time_steps 77189 learning_steps 77
# episode 448 score 25.7 avg score 36.3 time_steps 77376 learning_steps 77
# episode 449 score -6.3 avg score 36.1 time_steps 77402 learning_steps 77
# episode 450 score 14.4 avg score 36.2 time_steps 77514 learning_steps 77
# episode 451 score 5.1 avg score 36.3 time_steps 77612 learning_steps 77
# episode 452 score 39.4 avg score 36.6 time_steps 77824 learning_steps 77
# episode 453 score -3.8 avg score 36.6 time_steps 77900 learning_steps 77
# episode 454 score 21.8 avg score 36.6 time_steps 78164 learning_steps 78
# episode 455 score -6.8 avg score 36.4 time_steps 78200 learning_steps 78
# episode 456 score -6.2 avg score 36.2 time_steps 78224 learning_steps 78
# episode 457 score -2.5 avg score 36.1 time_steps 78275 learning_steps 78
# episode 458 score 10.7 avg score 36.0 time_steps 78361 learning_steps 78
# episode 459 score 55.6 avg score 36.7 time_steps 78650 learning_steps 78
# episode 460 score -6.2 avg score 36.7 time_steps 78674 learning_steps 78
# episode 461 score 16.9 avg score 36.5 time_steps 78835 learning_steps 78
# episode 462 score -6.9 avg score 35.4 time_steps 78872 learning_steps 78
# episode 463 score -6.2 avg score 35.0 time_steps 78897 learning_steps 78
# episode 464 score -6.8 avg score 35.0 time_steps 78933 learning_steps 78
# episode 465 score 18.8 avg score 34.6 time_steps 79058 learning_steps 79
# episode 466 score -0.0 avg score 34.1 time_steps 79159 learning_steps 79
# episode 467 score 1.9 avg score 33.2 time_steps 79221 learning_steps 79
# episode 468 score 35.6 avg score 33.4 time_steps 79409 learning_steps 79
# episode 469 score 5.1 avg score 33.2 time_steps 79507 learning_steps 79
# episode 470 score 29.3 avg score 33.5 time_steps 79721 learning_steps 79
# episode 471 score -6.2 avg score 32.9 time_steps 79746 learning_steps 79
# episode 472 score -2.4 avg score 32.3 time_steps 79795 learning_steps 79
# episode 473 score 1.9 avg score 32.3 time_steps 79857 learning_steps 79
# episode 474 score 23.2 avg score 32.6 time_steps 79994 learning_steps 79
# episode 475 score 2.6 avg score 32.6 time_steps 80043 learning_steps 80
# episode 476 score 7.5 avg score 32.6 time_steps 80193 learning_steps 80
# episode 477 score 9.4 avg score 32.1 time_steps 80305 learning_steps 80
# episode 478 score -0.7 avg score 32.2 time_steps 80419 learning_steps 80
# episode 479 score -6.1 avg score 32.1 time_steps 80442 learning_steps 80
# episode 480 score -6.2 avg score 31.3 time_steps 80467 learning_steps 80
# episode 481 score -7.5 avg score 30.8 time_steps 80517 learning_steps 80
# episode 482 score -6.2 avg score 30.7 time_steps 80542 learning_steps 80
# episode 483 score -6.1 avg score 30.4 time_steps 80565 learning_steps 80
# episode 484 score 9.4 avg score 30.5 time_steps 80677 learning_steps 80
# episode 485 score -6.2 avg score 30.4 time_steps 80701 learning_steps 80
# episode 486 score -6.3 avg score 30.3 time_steps 80726 learning_steps 80
# episode 487 score 6.2 avg score 30.0 time_steps 80801 learning_steps 80
# episode 488 score 12.0 avg score 29.5 time_steps 80961 learning_steps 80
# episode 489 score 31.2 avg score 29.7 time_steps 81238 learning_steps 81
# episode 490 score 68.0 avg score 30.4 time_steps 81679 learning_steps 81
# episode 491 score 0.7 avg score 30.1 time_steps 81865 learning_steps 81
# episode 492 score -6.3 avg score 30.0 time_steps 81891 learning_steps 81
# episode 493 score 44.3 avg score 30.4 time_steps 82204 learning_steps 82
# episode 494 score -6.2 avg score 28.1 time_steps 82229 learning_steps 82
# episode 495 score 1.4 avg score 28.2 time_steps 82301 learning_steps 82
# episode 496 score 40.5 avg score 26.5 time_steps 82591 learning_steps 82
# episode 497 score -6.8 avg score 26.4 time_steps 82628 learning_steps 82
# episode 498 score 15.6 avg score 24.6 time_steps 82816 learning_steps 82
# episode 499 score -8.1 avg score 22.9 time_steps 82878 learning_steps 82
# episode 500 score 6.3 avg score 22.9 time_steps 82952 learning_steps 82
# episode 501 score -6.3 avg score 22.9 time_steps 82977 learning_steps 82
# episode 502 score 35.0 avg score 22.9 time_steps 83278 learning_steps 83
# episode 503 score 54.3 avg score 22.6 time_steps 83591 learning_steps 83
# episode 504 score 10.1 avg score 21.5 time_steps 83689 learning_steps 83
# episode 505 score -6.8 avg score 21.3 time_steps 83725 learning_steps 83
# episode 506 score -6.9 avg score 20.9 time_steps 83764 learning_steps 83
# episode 507 score 33.2 avg score 20.1 time_steps 84001 learning_steps 84
# episode 508 score 18.7 avg score 20.4 time_steps 84228 learning_steps 84
# episode 509 score -6.2 avg score 20.2 time_steps 84251 learning_steps 84
# episode 510 score 33.1 avg score 19.5 time_steps 84490 learning_steps 84
# episode 511 score 136.1 avg score 18.3 time_steps 85268 learning_steps 85
# episode 512 score -8.1 avg score 17.6 time_steps 85330 learning_steps 85
# episode 513 score 26.3 avg score 17.5 time_steps 85505 learning_steps 85
# episode 514 score 27.4 avg score 17.7 time_steps 85757 learning_steps 85
# episode 515 score 31.9 avg score 17.0 time_steps 86019 learning_steps 86
# episode 516 score 26.2 avg score 17.4 time_steps 86195 learning_steps 86
# episode 517 score 10.7 avg score 17.2 time_steps 86382 learning_steps 86
# episode 518 score 59.9 avg score 17.8 time_steps 86784 learning_steps 86
# episode 519 score 186.0 avg score 19.7 time_steps 87864 learning_steps 87
# episode 520 score 6.3 avg score 19.9 time_steps 88039 learning_steps 88
# episode 521 score 150.5 avg score 20.8 time_steps 88829 learning_steps 88
# episode 522 score 252.2 avg score 22.2 time_steps 89985 learning_steps 89
# episode 523 score -3.1 avg score 22.0 time_steps 90147 learning_steps 90
# episode 524 score 69.3 avg score 22.4 time_steps 90461 learning_steps 90
# episode 525 score -6.2 avg score 22.3 time_steps 90485 learning_steps 90
# episode 526 score 5.1 avg score 22.4 time_steps 90583 learning_steps 90
# episode 527 score 61.7 avg score 20.9 time_steps 91049 learning_steps 91
# episode 528 score 259.1 avg score 23.3 time_steps 92468 learning_steps 92
# episode 529 score 63.1 avg score 23.6 time_steps 92907 learning_steps 92
# episode 530 score 6.3 avg score 23.7 time_steps 93081 learning_steps 93
# episode 531 score 89.9 avg score 23.7 time_steps 93483 learning_steps 93
# episode 532 score 1.9 avg score 23.8 time_steps 93646 learning_steps 93
# episode 533 score 123.6 avg score 25.0 time_steps 94274 learning_steps 94
# episode 534 score -2.5 avg score 25.0 time_steps 94424 learning_steps 94
# episode 535 score 42.5 avg score 24.4 time_steps 94674 learning_steps 94
# episode 536 score -9.9 avg score 24.0 time_steps 94773 learning_steps 94
# episode 537 score 143.6 avg score 24.4 time_steps 95401 learning_steps 95
# episode 538 score 49.3 avg score 25.0 time_steps 95815 learning_steps 95
# episode 539 score -6.8 avg score 24.9 time_steps 95850 learning_steps 95
# episode 540 score 41.8 avg score 25.3 time_steps 96115 learning_steps 96
# episode 541 score 32.5 avg score 25.6 time_steps 96365 learning_steps 96
# episode 542 score 371.5 avg score 28.7 time_steps 98036 learning_steps 98
# episode 543 score 5.0 avg score 28.9 time_steps 98136 learning_steps 98
# episode 544 score 26.3 avg score 28.4 time_steps 98311 learning_steps 98
# episode 545 score 55.1 avg score 29.0 time_steps 98610 learning_steps 98
# episode 546 score -8.7 avg score 29.0 time_steps 98685 learning_steps 98
# episode 547 score 102.3 avg score 30.0 time_steps 99140 learning_steps 99
# episode 548 score -8.0 avg score 29.7 time_steps 99301 learning_steps 99
# episode 549 score 134.3 avg score 31.1 time_steps 99916 learning_steps 99
# episode 550 score 64.9 avg score 31.6 time_steps 100318 learning_steps 100
# episode 551 score -3.6 avg score 31.5 time_steps 100491 learning_steps 100
# episode 552 score 49.3 avg score 31.6 time_steps 100806 learning_steps 100
# episode 553 score 43.7 avg score 32.1 time_steps 101133 learning_steps 101
# episode 554 score 38.2 avg score 32.3 time_steps 101370 learning_steps 101
# episode 555 score 42.5 avg score 32.8 time_steps 101621 learning_steps 101
# episode 556 score 78.0 avg score 33.6 time_steps 102060 learning_steps 102
# episode 557 score 15.0 avg score 33.8 time_steps 102160 learning_steps 102
# episode 558 score 60.0 avg score 34.3 time_steps 102561 learning_steps 102
# episode 559 score 1.3 avg score 33.7 time_steps 102735 learning_steps 102
# episode 560 score 5.0 avg score 33.8 time_steps 102835 learning_steps 102
# episode 561 score 5.1 avg score 33.7 time_steps 102934 learning_steps 102
# episode 562 score 70.5 avg score 34.5 time_steps 103324 learning_steps 103
# episode 563 score 26.9 avg score 34.8 time_steps 103587 learning_steps 103
# episode 564 score 78.7 avg score 35.7 time_steps 104113 learning_steps 104
# episode 565 score -6.3 avg score 35.4 time_steps 104139 learning_steps 104
# episode 566 score 15.6 avg score 35.6 time_steps 104227 learning_steps 104
# episode 567 score -6.1 avg score 35.5 time_steps 104250 learning_steps 104
# episode 568 score 10.0 avg score 35.3 time_steps 104350 learning_steps 104
# episode 569 score 21.3 avg score 35.4 time_steps 104525 learning_steps 104
# episode 570 score 92.4 avg score 36.0 time_steps 105077 learning_steps 105
# episode 571 score 55.0 avg score 36.7 time_steps 105478 learning_steps 105
# ... saving models ...
# episode 572 score 126.1 avg score 37.9 time_steps 106156 learning_steps 106
# episode 573 score -9.4 avg score 37.8 time_steps 106244 learning_steps 106
# ... saving models ...
# episode 574 score 62.5 avg score 38.2 time_steps 106594 learning_steps 106
# episode 575 score -6.2 avg score 38.1 time_steps 106619 learning_steps 106
# episode 576 score 6.3 avg score 38.1 time_steps 106694 learning_steps 106
# ... saving models ...
# episode 577 score 133.7 avg score 39.4 time_steps 107421 learning_steps 107
# episode 578 score -8.7 avg score 39.3 time_steps 107496 learning_steps 107
# ... saving models ...
# episode 579 score 7.5 avg score 39.4 time_steps 107747 learning_steps 107
# episode 580 score -6.2 avg score 39.4 time_steps 107772 learning_steps 107
# ... saving models ...
# episode 581 score 171.1 avg score 41.2 time_steps 108651 learning_steps 108
# ... saving models ...
# episode 582 score 70.5 avg score 42.0 time_steps 109140 learning_steps 109
# ... saving models ...
# episode 583 score 28.8 avg score 42.3 time_steps 109465 learning_steps 109
# ... saving models ...
# episode 584 score 32.4 avg score 42.6 time_steps 109717 learning_steps 109
# episode 585 score -6.8 avg score 42.5 time_steps 109754 learning_steps 109
# ... saving models ...
# episode 586 score 88.1 avg score 43.5 time_steps 110193 learning_steps 110
# ... saving models ...
# episode 587 score 6.9 avg score 43.5 time_steps 110356 learning_steps 110
# ... saving models ...
# episode 588 score 131.1 avg score 44.7 time_steps 111034 learning_steps 111
# episode 589 score 0.7 avg score 44.4 time_steps 111121 learning_steps 111
# ... saving models ...
# episode 590 score 133.6 avg score 45.0 time_steps 111748 learning_steps 111
# ... saving models ...
# episode 591 score 73.0 avg score 45.8 time_steps 112188 learning_steps 112
# episode 592 score -8.1 avg score 45.7 time_steps 112250 learning_steps 112
# ... saving models ...
# episode 593 score 121.1 avg score 46.5 time_steps 112928 learning_steps 112
# episode 594 score -7.4 avg score 46.5 time_steps 112977 learning_steps 112
# ... saving models ...
# episode 595 score 15.0 avg score 46.6 time_steps 113077 learning_steps 113
# episode 596 score -6.2 avg score 46.2 time_steps 113102 learning_steps 113
# ... saving models ...
# episode 597 score 43.8 avg score 46.7 time_steps 113325 learning_steps 113
# ... saving models ...
# episode 598 score 41.8 avg score 46.9 time_steps 113689 learning_steps 113
# ... saving models ...
# episode 599 score 77.4 avg score 47.8 time_steps 114242 learning_steps 114
# episode 600 score 1.9 avg score 47.7 time_steps 114404 learning_steps 114
# ... saving models ...
# episode 601 score 31.2 avg score 48.1 time_steps 114580 learning_steps 114
# episode 602 score 10.0 avg score 47.9 time_steps 114680 learning_steps 114
# ... saving models ...
# episode 603 score 323.5 avg score 50.6 time_steps 116009 learning_steps 116
# ... saving models ...
# episode 604 score 16.2 avg score 50.6 time_steps 116185 learning_steps 116
# ... saving models ...
# episode 605 score 21.2 avg score 50.9 time_steps 116360 learning_steps 116
# ... saving models ...
# episode 606 score 22.6 avg score 51.2 time_steps 116508 learning_steps 116
# episode 607 score 26.2 avg score 51.1 time_steps 116684 learning_steps 116
# episode 608 score 3.1 avg score 51.0 time_steps 116821 learning_steps 116
# ... saving models ...
# episode 609 score 167.9 avg score 52.7 time_steps 117563 learning_steps 117
# episode 610 score -8.1 avg score 52.3 time_steps 117625 learning_steps 117
# episode 611 score 19.4 avg score 51.1 time_steps 117738 learning_steps 117
# episode 612 score 76.3 avg score 52.0 time_steps 118112 learning_steps 118
# episode 613 score -6.3 avg score 51.7 time_steps 118137 learning_steps 118
# episode 614 score 15.0 avg score 51.5 time_steps 118237 learning_steps 118
# episode 615 score 5.0 avg score 51.3 time_steps 118337 learning_steps 118
# episode 616 score 68.7 avg score 51.7 time_steps 118663 learning_steps 118
# episode 617 score -6.2 avg score 51.5 time_steps 118687 learning_steps 118
# episode 618 score 120.5 avg score 52.1 time_steps 119277 learning_steps 119
# episode 619 score -7.5 avg score 50.2 time_steps 119327 learning_steps 119
# episode 620 score -6.2 avg score 50.1 time_steps 119351 learning_steps 119
# episode 621 score 367.7 avg score 52.2 time_steps 120997 learning_steps 120
# episode 622 score 30.0 avg score 50.0 time_steps 121397 learning_steps 121
# episode 623 score 38.7 avg score 50.4 time_steps 121723 learning_steps 121
# ...
# episode 845 score 57.5 avg score 41.2 time_steps 182691 learning_steps 182
# episode 846 score 13.1 avg score 40.9 time_steps 182830 learning_steps 182
# episode 847 score 39.4 avg score 41.0 time_steps 183042 learning_steps 183
# episode 848 score 42.5 avg score 40.9 time_steps 183292 learning_steps 183
# episode 849 score 2.0 avg score 37.6 time_steps 183452 learning_steps 183
# episode 850 score 58.6 avg score 36.6 time_steps 183780 learning_steps 183
# episode 851 score 32.5 avg score 36.6 time_steps 184031 learning_steps 184
# episode 852 score 9.4 avg score 36.8 time_steps 184143 learning_steps 184
# episode 853 score 5.0 avg score 35.4 time_steps 184243 learning_steps 184
# episode 854 score 5.1 avg score 33.5 time_steps 184342 learning_steps 184
# episode 855 score 18.1 avg score 33.1 time_steps 184481 learning_steps 184
# episode 856 score 201.1 avg score 34.2 time_steps 185460 learning_steps 185
# episode 857 score -6.8 avg score 34.2 time_steps 185497 learning_steps 185
# episode 858 score 10.0 avg score 32.8 time_steps 185597 learning_steps 185
# episode 859 score -6.7 avg score 32.5 time_steps 185632 learning_steps 185
# episode 860 score -6.3 avg score 31.9 time_steps 185658 learning_steps 185
# episode 861 score 42.6 avg score 31.9 time_steps 185907 learning_steps 185
# episode 862 score 136.1 avg score 32.4 time_steps 186685 learning_steps 186
# episode 863 score 277.1 avg score 35.2 time_steps 188144 learning_steps 188
# episode 864 score -8.7 avg score 35.2 time_steps 188218 learning_steps 188
# episode 865 score -6.2 avg score 34.5 time_steps 188242 learning_steps 188
# episode 866 score 68.7 avg score 33.9 time_steps 188569 learning_steps 188
# episode 867 score -6.8 avg score 33.8 time_steps 188606 learning_steps 188
# episode 868 score 124.3 avg score 33.8 time_steps 189121 learning_steps 189
# episode 869 score 60.6 avg score 34.5 time_steps 189509 learning_steps 189
# episode 870 score -6.2 avg score 33.8 time_steps 189533 learning_steps 189
# episode 871 score 15.0 avg score 33.9 time_steps 189633 learning_steps 189
# episode 872 score 85.0 avg score 33.9 time_steps 190034 learning_steps 190
# episode 873 score 85.0 avg score 34.4 time_steps 190435 learning_steps 190
# episode 874 score -10.5 avg score 33.9 time_steps 190546 learning_steps 190
# episode 875 score -6.8 avg score 33.9 time_steps 190583 learning_steps 190
# episode 876 score 254.7 avg score 36.3 time_steps 191689 learning_steps 191
# episode 877 score 170.4 avg score 38.0 time_steps 192581 learning_steps 192
# episode 878 score 241.6 avg score 40.0 time_steps 193648 learning_steps 193
# episode 879 score 45.7 avg score 40.1 time_steps 194035 learning_steps 194
# episode 880 score 66.1 avg score 40.2 time_steps 194413 learning_steps 194
# episode 881 score 11.9 avg score 40.4 time_steps 194575 learning_steps 194
# episode 882 score 33.8 avg score 40.1 time_steps 194798 learning_steps 194
# episode 883 score 89.9 avg score 41.0 time_steps 195401 learning_steps 195
# episode 884 score -2.5 avg score 40.2 time_steps 195551 learning_steps 195
# episode 885 score 10.0 avg score 40.3 time_steps 195652 learning_steps 195
# episode 886 score -3.1 avg score 39.1 time_steps 195714 learning_steps 195
# episode 887 score 58.2 avg score 39.3 time_steps 196051 learning_steps 196
# episode 888 score -6.9 avg score 39.1 time_steps 196090 learning_steps 196
# episode 889 score 9.4 avg score 39.2 time_steps 196202 learning_steps 196
# episode 890 score 35.6 avg score 39.4 time_steps 196390 learning_steps 196
# episode 891 score -6.2 avg score 39.2 time_steps 196414 learning_steps 196
# episode 892 score 14.5 avg score 38.8 time_steps 196525 learning_steps 196
# episode 893 score 28.1 avg score 38.7 time_steps 196764 learning_steps 196
# episode 894 score -5.5 avg score 38.3 time_steps 196875 learning_steps 196
# episode 895 score 30.5 avg score 38.5 time_steps 197064 learning_steps 197
# episode 896 score -3.1 avg score 38.0 time_steps 197126 learning_steps 197
# episode 897 score 63.1 avg score 38.8 time_steps 197464 learning_steps 197
# episode 898 score -6.2 avg score 38.3 time_steps 197489 learning_steps 197
# episode 899 score 44.4 avg score 38.1 time_steps 197702 learning_steps 197
# episode 900 score 86.8 avg score 38.1 time_steps 198167 learning_steps 198
# episode 901 score 1.3 avg score 38.1 time_steps 198341 learning_steps 198
# episode 902 score 1.9 avg score 37.7 time_steps 198404 learning_steps 198
# episode 903 score 70.6 avg score 38.3 time_steps 198792 learning_steps 198
# episode 904 score -6.7 avg score 38.3 time_steps 198827 learning_steps 198
# episode 905 score -6.9 avg score 37.8 time_steps 198865 learning_steps 198
# episode 906 score 17.0 avg score 37.7 time_steps 199026 learning_steps 199
# episode 907 score 149.8 avg score 39.2 time_steps 199831 learning_steps 199
# episode 908 score 27.5 avg score 39.1 time_steps 200082 learning_steps 200
# episode 909 score -6.1 avg score 38.8 time_steps 200105 learning_steps 200
# episode 910 score 33.8 avg score 38.5 time_steps 200329 learning_steps 200
# episode 911 score 9.4 avg score 38.6 time_steps 200442 learning_steps 200
# episode 912 score 13.8 avg score 38.5 time_steps 200567 learning_steps 200
# episode 913 score 1.2 avg score 38.5 time_steps 200643 learning_steps 200
# episode 914 score -6.7 avg score 38.4 time_steps 200678 learning_steps 200
# episode 915 score 11.3 avg score 37.4 time_steps 200753 learning_steps 200
# episode 916 score 25.6 avg score 37.5 time_steps 200941 learning_steps 200
# episode 917 score 13.8 avg score 37.7 time_steps 201066 learning_steps 201
# episode 918 score -6.2 avg score 37.3 time_steps 201091 learning_steps 201
# episode 919 score -6.8 avg score 37.3 time_steps 201127 learning_steps 201
# episode 920 score -6.3 avg score 36.4 time_steps 201154 learning_steps 201
# episode 921 score 26.3 avg score 36.7 time_steps 201329 learning_steps 201
# episode 922 score 5.0 avg score 36.4 time_steps 201429 learning_steps 201
# episode 923 score 35.7 avg score 36.2 time_steps 201615 learning_steps 201
# episode 924 score -8.2 avg score 36.2 time_steps 201678 learning_steps 201
# episode 925 score 25.6 avg score 35.4 time_steps 201866 learning_steps 201
# episode 926 score -6.7 avg score 35.1 time_steps 201900 learning_steps 201
# episode 927 score 114.2 avg score 36.3 time_steps 202517 learning_steps 202
# episode 928 score -8.7 avg score 35.8 time_steps 202591 learning_steps 202
# episode 929 score 0.0 avg score 35.9 time_steps 202691 learning_steps 202
# episode 930 score 15.1 avg score 36.1 time_steps 202789 learning_steps 202
# episode 931 score -6.8 avg score 35.9 time_steps 202826 learning_steps 202
# episode 932 score 36.2 avg score 36.3 time_steps 203102 learning_steps 203
# episode 933 score 59.9 avg score 36.8 time_steps 203504 learning_steps 203
# episode 934 score 6.2 avg score 36.8 time_steps 203580 learning_steps 203
# episode 935 score 6.3 avg score 36.2 time_steps 203654 learning_steps 203
# episode 936 score -6.2 avg score 36.1 time_steps 203677 learning_steps 203
# episode 937 score -6.3 avg score 36.1 time_steps 203703 learning_steps 203
# episode 938 score -6.2 avg score 35.7 time_steps 203726 learning_steps 203
# episode 939 score 14.4 avg score 34.4 time_steps 203839 learning_steps 203
# episode 940 score -6.2 avg score 34.2 time_steps 203863 learning_steps 203
# episode 941 score 227.3 avg score 35.4 time_steps 204917 learning_steps 204
# episode 942 score 1.9 avg score 34.5 time_steps 205080 learning_steps 205
# episode 943 score 63.6 avg score 35.2 time_steps 205408 learning_steps 205
# episode 944 score -6.3 avg score 34.9 time_steps 205433 learning_steps 205
# episode 945 score -1.7 avg score 34.3 time_steps 205468 learning_steps 205
# episode 946 score 6.3 avg score 34.3 time_steps 205542 learning_steps 205
# episode 947 score 309.0 avg score 37.0 time_steps 206862 learning_steps 206
# episode 948 score 11.3 avg score 36.6 time_steps 207037 learning_steps 207
# episode 949 score 1.9 avg score 36.6 time_steps 207099 learning_steps 207
# episode 950 score 3.9 avg score 36.1 time_steps 207222 learning_steps 207
# episode 951 score 78.1 avg score 36.6 time_steps 207560 learning_steps 207
# episode 952 score 227.3 avg score 38.7 time_steps 208614 learning_steps 208
# episode 953 score 53.0 avg score 39.2 time_steps 208955 learning_steps 208
# episode 954 score 10.7 avg score 39.3 time_steps 209141 learning_steps 209
# episode 955 score 53.6 avg score 39.6 time_steps 209468 learning_steps 209
# episode 956 score -8.1 avg score 37.5 time_steps 209531 learning_steps 209
# episode 957 score 101.2 avg score 38.6 time_steps 210007 learning_steps 210
# episode 958 score 86.9 avg score 39.4 time_steps 210470 learning_steps 210
# episode 959 score 38.0 avg score 39.8 time_steps 210810 learning_steps 210
# episode 960 score 18.7 avg score 40.1 time_steps 211136 learning_steps 211
# episode 961 score 33.7 avg score 40.0 time_steps 211462 learning_steps 211
# episode 962 score 70.0 avg score 39.3 time_steps 211863 learning_steps 211
# episode 963 score 103.6 avg score 37.6 time_steps 212390 learning_steps 212
# episode 964 score -10.0 avg score 37.6 time_steps 212490 learning_steps 212
# episode 965 score 54.5 avg score 38.2 time_steps 212801 learning_steps 212
# episode 966 score 141.7 avg score 38.9 time_steps 213568 learning_steps 213
# episode 967 score 101.7 avg score 40.0 time_steps 214134 learning_steps 214
# episode 968 score 58.7 avg score 39.3 time_steps 214460 learning_steps 214
# episode 969 score -10.0 avg score 38.6 time_steps 214560 learning_steps 214
# episode 970 score 0.1 avg score 38.7 time_steps 214658 learning_steps 214
# episode 971 score 58.6 avg score 39.1 time_steps 214986 learning_steps 214
# episode 972 score 26.9 avg score 38.6 time_steps 215248 learning_steps 215
# episode 973 score 11.2 avg score 37.8 time_steps 215423 learning_steps 215
# episode 974 score 43.7 avg score 38.4 time_steps 215749 learning_steps 215
# episode 975 score 28.8 avg score 38.7 time_steps 216073 learning_steps 216
# episode 976 score 112.3 avg score 37.3 time_steps 216626 learning_steps 216
# episode 977 score -6.8 avg score 35.5 time_steps 216662 learning_steps 216
# episode 978 score 11.3 avg score 33.2 time_steps 216737 learning_steps 216
# episode 979 score 15.0 avg score 32.9 time_steps 216838 learning_steps 216
# episode 980 score -6.2 avg score 32.2 time_steps 216862 learning_steps 216
# episode 981 score 52.5 avg score 32.6 time_steps 217113 learning_steps 217
# episode 982 score 50.0 avg score 32.8 time_steps 217513 learning_steps 217
# episode 983 score 64.8 avg score 32.5 time_steps 217916 learning_steps 217
# episode 984 score 97.5 avg score 33.5 time_steps 218467 learning_steps 218
# episode 985 score -6.2 avg score 33.4 time_steps 218490 learning_steps 218
# episode 986 score 2.5 avg score 33.4 time_steps 218539 learning_steps 218
# episode 987 score 5.0 avg score 32.9 time_steps 218640 learning_steps 218
# episode 988 score 21.3 avg score 33.2 time_steps 218815 learning_steps 218
# episode 989 score 193.0 avg score 35.0 time_steps 219856 learning_steps 219
# episode 990 score -6.8 avg score 34.6 time_steps 219893 learning_steps 219
# episode 991 score 36.2 avg score 35.0 time_steps 220070 learning_steps 220
# episode 992 score 81.8 avg score 35.7 time_steps 220533 learning_steps 220
# episode 993 score -9.9 avg score 35.3 time_steps 220632 learning_steps 220
# episode 994 score 63.6 avg score 36.0 time_steps 221060 learning_steps 221
# episode 995 score 116.2 avg score 36.8 time_steps 221637 learning_steps 221
# episode 996 score 23.1 avg score 37.1 time_steps 221975 learning_steps 221
# episode 997 score 188.5 avg score 38.3 time_steps 223106 learning_steps 223
# episode 998 score -6.7 avg score 38.3 time_steps 223141 learning_steps 223
# episode 999 score 48.0 avg score 38.4 time_steps 223481 learning_steps 223
# episode 1000 score -6.7 avg score 37.4 time_steps 223516 learning_steps 223
# episode 1001 score -6.3 avg score 37.4 time_steps 223542 learning_steps 223
# episode 1002 score 58.7 avg score 37.9 time_steps 223968 learning_steps 223
# episode 1003 score 31.2 avg score 37.5 time_steps 224244 learning_steps 224
# episode 1004 score 149.2 avg score 39.1 time_steps 225060 learning_steps 225
# episode 1005 score -6.1 avg score 39.1 time_steps 225083 learning_steps 225
# episode 1006 score 5.7 avg score 39.0 time_steps 225169 learning_steps 225
# episode 1007 score 91.0 avg score 38.4 time_steps 225649 learning_steps 225
# episode 1008 score -6.8 avg score 38.1 time_steps 225685 learning_steps 225
# episode 1009 score 89.9 avg score 39.0 time_steps 226187 learning_steps 226
# episode 1010 score -6.8 avg score 38.6 time_steps 226223 learning_steps 226
# episode 1011 score 4.4 avg score 38.6 time_steps 226335 learning_steps 226
# episode 1012 score 31.8 avg score 38.8 time_steps 226599 learning_steps 226
# episode 1013 score -7.4 avg score 38.7 time_steps 226647 learning_steps 226
# episode 1014 score 53.8 avg score 39.3 time_steps 226971 learning_steps 226
# episode 1015 score 22.4 avg score 39.4 time_steps 227223 learning_steps 227
# episode 1016 score 12.6 avg score 39.3 time_steps 227371 learning_steps 227
# episode 1017 score 42.4 avg score 39.5 time_steps 227623 learning_steps 227
# episode 1018 score -9.9 avg score 39.5 time_steps 227722 learning_steps 227
# episode 1019 score 35.6 avg score 39.9 time_steps 227910 learning_steps 227
# episode 1020 score 3.2 avg score 40.0 time_steps 228046 learning_steps 228
# episode 1021 score -2.5 avg score 39.7 time_steps 228097 learning_steps 228
# episode 1022 score -6.9 avg score 39.6 time_steps 228135 learning_steps 228
# episode 1023 score -6.8 avg score 39.2 time_steps 228171 learning_steps 228
# episode 1024 score 8.8 avg score 39.4 time_steps 228294 learning_steps 228
# episode 1025 score 26.1 avg score 39.4 time_steps 228572 learning_steps 228
# episode 1026 score -6.8 avg score 39.4 time_steps 228609 learning_steps 228
# episode 1027 score 104.3 avg score 39.3 time_steps 229224 learning_steps 229
# episode 1028 score 95.0 avg score 40.3 time_steps 229724 learning_steps 229
# episode 1029 score -7.4 avg score 40.2 time_steps 229773 learning_steps 229
# episode 1030 score 26.3 avg score 40.3 time_steps 229948 learning_steps 229
# episode 1031 score -6.3 avg score 40.3 time_steps 229974 learning_steps 229
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# f:\Nathan\!SKRIPSI\rl-wave\ppo_utub.ipynb Cell 3' in <cell line: 27>()
#      <a href='vscode-notebook-cell:/f%3A/Nathan/%21SKRIPSI/rl-wave/ppo_utub.ipynb#ch0000001?line=35'>36</a> agent.remember(observation, action, prob, val, reward, done)
#      <a href='vscode-notebook-cell:/f%3A/Nathan/%21SKRIPSI/rl-wave/ppo_utub.ipynb#ch0000001?line=36'>37</a> if n_steps % N == 0:
# ---> <a href='vscode-notebook-cell:/f%3A/Nathan/%21SKRIPSI/rl-wave/ppo_utub.ipynb#ch0000001?line=37'>38</a>     agent.learn()
#      <a href='vscode-notebook-cell:/f%3A/Nathan/%21SKRIPSI/rl-wave/ppo_utub.ipynb#ch0000001?line=38'>39</a>     learn_iters += 1
#      <a href='vscode-notebook-cell:/f%3A/Nathan/%21SKRIPSI/rl-wave/ppo_utub.ipynb#ch0000001?line=39'>40</a> observation = observation_
#
# f:\Nathan\!SKRIPSI\rl-wave\ppo_utub.ipynb Cell 1' in Agent.learn(self)
#     <a href='vscode-notebook-cell:/f%3A/Nathan/%21SKRIPSI/rl-wave/ppo_utub.ipynb#ch0000000?line=159'>160</a>     for k in range(t, len(reward_arr)-1):
#     <a href='vscode-notebook-cell:/f%3A/Nathan/%21SKRIPSI/rl-wave/ppo_utub.ipynb#ch0000000?line=160'>161</a>         a_t += discount*(reward_arr[k] + self.gamma*values[k+1]*\
#     <a href='vscode-notebook-cell:/f%3A/Nathan/%21SKRIPSI/rl-wave/ppo_utub.ipynb#ch0000000?line=161'>162</a>                 (1-int(dones_arr[k])) - values[k])
# --> <a href='vscode-notebook-cell:/f%3A/Nathan/%21SKRIPSI/rl-wave/ppo_utub.ipynb#ch0000000?line=162'>163</a>         discount *= self.gamma*self.gae_lambda
#     <a href='vscode-notebook-cell:/f%3A/Nathan/%21SKRIPSI/rl-wave/ppo_utub.ipynb#ch0000000?line=163'>164</a>     advantage[t] = a_t
#     <a href='vscode-notebook-cell:/f%3A/Nathan/%21SKRIPSI/rl-wave/ppo_utub.ipynb#ch0000000?line=164'>165</a> advantage = T.tensor(advantage).to(self.actor.device)
#
# KeyboardInterrupt:

# %%
env.close()
