# %%
import gym

from stable_baselines3 import A2C
from stable_baselines3.common.env_util import make_vec_env

# Parallel environments
env = make_vec_env("CartPole-v1", n_envs=4)

model = A2C("MlpPolicy", env, verbose=1, learning_rate=1e-4, tensorboard_log="./cartpole-tensorboard/")
model.learn(total_timesteps=125000)
# Out:
# Using cpu device
# Logging to ./cartpole-tensorboard/A2C_2
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.5     |
# |    ep_rew_mean        | 21.5     |
# | time/                 |          |
# |    fps                | 3718     |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 0.126    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 1.83     |
# |    value_loss         | 8.83     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.5     |
# |    ep_rew_mean        | 22.5     |
# | time/                 |          |
# |    fps                | 3634     |
# |    iterations         | 200      |
# ...

# %%
import gym
import numpy as np

from stable_baselines3 import DQN

env = gym.make("CartPole-v1")

model = DQN("MlpPolicy", env, verbose=1, tensorboard_log="./cartpole-tensorboard/")
model.learn(total_timesteps=125000, log_interval=4)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./cartpole-tensorboard/DQN_2
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24       |
# |    ep_rew_mean      | 24       |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 2424     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 96       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 2674     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 163      |
# ----------------------------------
# ----------------------------------
# ...

# %%
sys.path.insert(0, './common')

import cartpole
import a2c_model
